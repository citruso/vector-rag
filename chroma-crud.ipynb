# %%
# %pip install langchain langchain-community langchain-text-splitters langchain_huggingface

# %%
# %pip install chromadb tiktoken pypdf sentence-transformers

# %% [markdown]
# ### Подготовка данных

# %%
from langchain_community.document_loaders import PyPDFLoader

# загружаем PDF файл
loader = PyPDFLoader('https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf')
pages = loader.load_and_split()
pages[0]
# Out:
# Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='Online Tracking:\nA 1-million-site Measurement and Analysis\nSteven Englehardt\nPrinceton University\nste@cs.princeton.edu\nArvind Narayanan\nPrinceton University\narvindn@cs.princeton.edu\nThis is an extended version of our paper that appeared at ACM CCS 2016.\nABSTRACT\nWe present the largest and most detailed measurement of\nonline tracking conducted to date, based on a crawl of the\ntop 1 million websites. We make 15 types of measurements\non each site, including stateful (cookie-based) and stateless\n(ﬁngerprinting-based) tracking, the eﬀect of browser privacy\ntools, and the exchange of tracking data between diﬀerent\nsites (“cookie syncing”). Our ﬁndings include multiple so-\nphisticated ﬁngerprinting techniques never before measured\nin the wild.\nThis measurement is made possible by our open-source\nweb privacy measurement tool, OpenWPM1, which uses an\nautomated version of a full-ﬂedged consumer browser. It\nsupports parallelism for speed and scale, automatic recovery\nfrom failures of the underlying browser, and comprehensive\nbrowser instrumentation. We demonstrate our platform’s\nstrength in enabling researchers to rapidly detect, quantify,\nand characterize emerging online tracking behaviors.\n1. INTRODUCTION\nWeb privacy measurement — observing websites and ser-\nvices to detect, characterize and quantify privacy-impacting\nbehaviors — has repeatedly forced companies to improve\ntheir privacy practices due to public pressure, press cov-\nerage, and regulatory action [5, 15]. On the other hand,\nweb privacy measurement presents formidable engineering\nand methodological challenges. In the absence of a generic\ntool, it has been largely conﬁned to a niche community of\nresearchers.\nWe seek to transform web privacy measurement into a\nwidespread practice by creating a tool that is useful not just\nto our colleagues but also to regulators, self-regulators, the\npress, activists, and website operators, who are often in the\ndark about third-party tracking on their own domains. We\nalso seek to lessen the burden of continual oversight of web\ntracking and privacy, by developing a robust and modular\nplatform for repeated studies.\nOpenWPM (Section 3) solves three key systems challenges\nfaced by the web privacy measurement community. It does\nso by building on the strengths of past work, while avoiding\nthe pitfalls made apparent in previous engineering eﬀorts.\n(1) We achieve scale through parallelism and robustness by\nutilizing isolated measurement processes similar to FPDetec-\ntive’s platform [2], while still supporting stateful measure-\nments. We’re able to scale to 1 million sites, without having\n1https://github.com/citp/OpenWPM\nto resort to a stripped-down browser [31] (a limitation we\nexplore in detail in Section 3.3). (2) We provide compre-\nhensive instrumentation by expanding on the rich browser\nextension instrumentation of FourthParty [33], without re-\nquiring the researcher to write their own automation code.\n(3) We reduce duplication of work by providing a modular\narchitecture to enable code re-use between studies.\nSolving these problems is hard because the web is not de-\nsigned for automation or instrumentation. Selenium, 2 the\nmain tool for automated browsing through a full-ﬂedged\nbrowser, is intended for developers to test their own web-\nsites. As a result it performs poorly on websites not con-\ntrolled by the user and breaks frequently if used for large-\n ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# разбиваем PDF на чанки
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=0)
splits = text_splitter.split_documents(pages)

# %%
splits
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='Online Tracking:\nA 1-million-site Measurement and Analysis\nSteven Englehardt\nPrinceton University\nste@cs.princeton.edu\nArvind Narayanan\nPrinceton University\narvindn@cs.princeton.edu\nThis is an extended version of our paper that appeared at ACM CCS 2016.\nABSTRACT\nWe present the largest and most detailed measurement of\nonline tracking conducted to date, based on a crawl of the\ntop 1 million websites. We make 15 types of measurements\non each site, including stateful (cookie-based) and stateless'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='(ﬁngerprinting-based) tracking, the eﬀect of browser privacy\ntools, and the exchange of tracking data between diﬀerent\nsites (“cookie syncing”). Our ﬁndings include multiple so-\nphisticated ﬁngerprinting techniques never before measured\nin the wild.\nThis measurement is made possible by our open-source\nweb privacy measurement tool, OpenWPM1, which uses an\nautomated version of a full-ﬂedged consumer browser. It\nsupports parallelism for speed and scale, automatic recovery'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='from failures of the underlying browser, and comprehensive\nbrowser instrumentation. We demonstrate our platform’s\nstrength in enabling researchers to rapidly detect, quantify,\nand characterize emerging online tracking behaviors.\n1. INTRODUCTION\nWeb privacy measurement — observing websites and ser-\nvices to detect, characterize and quantify privacy-impacting\nbehaviors — has repeatedly forced companies to improve\ntheir privacy practices due to public pressure, press cov-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='erage, and regulatory action [5, 15]. On the other hand,\nweb privacy measurement presents formidable engineering\nand methodological challenges. In the absence of a generic\ntool, it has been largely conﬁned to a niche community of\nresearchers.\nWe seek to transform web privacy measurement into a\nwidespread practice by creating a tool that is useful not just\nto our colleagues but also to regulators, self-regulators, the\npress, activists, and website operators, who are often in the'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='dark about third-party tracking on their own domains. We\nalso seek to lessen the burden of continual oversight of web\ntracking and privacy, by developing a robust and modular\nplatform for repeated studies.\nOpenWPM (Section 3) solves three key systems challenges\nfaced by the web privacy measurement community. It does\nso by building on the strengths of past work, while avoiding\nthe pitfalls made apparent in previous engineering eﬀorts.\n(1) We achieve scale through parallelism and robustness by'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='utilizing isolated measurement processes similar to FPDetec-\ntive’s platform [2], while still supporting stateful measure-\nments. We’re able to scale to 1 million sites, without having\n1https://github.com/citp/OpenWPM\nto resort to a stripped-down browser [31] (a limitation we\nexplore in detail in Section 3.3). (2) We provide compre-\nhensive instrumentation by expanding on the rich browser\nextension instrumentation of FourthParty [33], without re-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='quiring the researcher to write their own automation code.\n(3) We reduce duplication of work by providing a modular\narchitecture to enable code re-use between studies.\nSolving these problems is hard because the web is not de-\nsigned for automation or instrumentation. Selenium, 2 the\nmain tool for automated browsing through a full-ﬂedged\nbrowser, is intended for developers to test their own web-\nsites. As a result it performs poorly on websites not con-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='trolled by the user and breaks frequently if used for large-\nscale measurements. Browsers themselves tend to suﬀer\nmemory leaks over long sessions. In addition, instrument-\ning the browser to collect a variety of data for later analy-\nsis presents formidable challenges. For full coverage, we’ve\nfound it necessary to have three separate measurement points:\na network proxy, a browser extension, and a disk state mon-\nitor. Further, we must link data collected from these dis-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='parate points into a uniform schema, duplicating much of\nthe browser’s own internal logic in parsing traﬃc.\nA large-scale view of web tracking and privacy.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='parate points into a uniform schema, duplicating much of\nthe browser’s own internal logic in parsing traﬃc.\nA large-scale view of web tracking and privacy.\nIn this paper we report results from a January 2016 mea-\nsurement of the top 1 million sites (Section 4). Our scale\nenables a variety of new insights. We observe for the ﬁrst\ntime that online tracking has a “long tail”, but we ﬁnd a\nsurprisingly quick drop-oﬀ in the scale of individual track-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='ers: trackers in the tail are found on very few sites (Sec-\ntion 5.1). Using a new metric for quantifying tracking (Sec-\ntion 5.2), we ﬁnd that the tracking-protection tool Ghostery\n(https://www.ghostery.com/) is eﬀective, with some caveats\n(Section 5.5). We quantify the impact of trackers and third\nparties on HTTPS deployment (Section 5.3) and show that\ncookie syncing is pervasive (Section 5.6).\nTurning to browser ﬁngerprinting, we revisit an inﬂuential'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='2014 study on canvas ﬁngerprinting [1] with updated and im-\nproved methodology (Section 6.1). Next, we report on sev-\neral types of ﬁngerprinting never before measured at scale:\nfont ﬁngerprinting using canvas (which is distinct from can-\nvas ﬁngerprinting; Section 6.2), and ﬁngerprinting by abus-\ning the WebRTC API (Section 6.3), the Audio API (Section\n6.4), and the Battery Status API (6.5). Finally, we show\nthat in contrast to our results in Section 5.5, existing pri-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='vacy tools are not eﬀective at detecting these newer and\nmore obscure ﬁngerprinting techniques.\n2http://www.seleniumhq.org/'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='Overall, our results show cause for concern, but also en-\ncouraging signs. In particular, several of our results suggest\nthat while online tracking presents few barriers to entry,\ntrackers in the tail of the distribution are found on very few\nsites and are far less likely to be encountered by the av-\nerage user. Those at the head of the distribution, on the\nother hand, are owned by relatively few companies and are\nresponsive to the scrutiny resulting from privacy studies.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='We envision a future where measurement provides a key\nlayer of oversight of online privacy. This will be especially\nimportant given that perfectly anticipating and preventing\nall possible privacy problems (whether through blocking tools\nor careful engineering of web APIs) has proved infeasible.\nTo enable such oversight, we plan to make all of our data\npublicly available (OpenWPM is already open-source). We\nexpect that measurement will be useful to developers of pri-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='vacy tools, to regulators and policy makers, journalists, and\nmany others.\n2. BACKGROUND AND RELATED WORK\nBackground: third-party online tracking. As users\nbrowse and interact with websites, they are observed by both\n“ﬁrst parties,” which are the sites the user visits directly, and\n“third parties” which are typically hidden trackers such as\nad networks embedded on most web pages. Third parties\ncan obtain users’ browsing histories through a combination'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='of cookies and other tracking technologies that allow them\nto uniquely identify users, and the “referer” header that tells\nthe third party which ﬁrst-party site the user is currently\nvisiting. Other sensitive information such as email addresses\nmay also be leaked to third parties via the referer header.\nWeb privacy measurement platforms. The closest\ncomparisons to OpenWPM are other open web privacy mea-\nsurement platforms, which we now review. We consider a'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='tool to be a platform if is is publicly available and there is\nsome generality to the types of studies that can be performed\nusing it. In some cases, OpenWPM has directly built upon\nexisting platforms, which we make explicit note of.\nFPDetective is the most similar platform to OpenWPM.\nFPDetective uses a hybrid PhantomJS and Chromium based\nautomation infrastructure [2], with both native browser code\nand a proxy for instrumentation. In the published study, the'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='platform was used for the detection and analysis of ﬁnger-\nprinters, and much of the included instrumentation was built\nto support that. The platform allows researchers to conduct\nadditional experiments by replacing a script which is exe-\ncuted with each page visit, which the authors state can be\neasily extended for non-ﬁngerprinting studies.\nOpenWPM diﬀers in several ways from FPDetective: (1)\nit supports both stateful and stateless measurements, whereas'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='FPDetective only supports stateless (2) it includes generic\ninstrumentation for both stateless and stateful tracking, en-\nabling a wider range of privacy studies without additional\nchanges to the infrastructure (3) none of the included instru-\nmentation requires native browser code, making it easier to\nupgrade to new or diﬀerent versions of the browser, and (4)\nOpenWPM uses a high-level command-based architecture,\nwhich supports command re-use between studies.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='Chameleon Crawler is a Chromium based crawler that uti-\nlizes the Chameleon3 browser extension for detecting browser\nﬁngerprinting. Chameleon Crawler uses similar automation\n3https://github.com/ghostwords/chameleon\ncomponents, but supports a subset of OpenWPM’s instru-\nmentation.\nFourthParty is a Firefox plug-in for instrumenting the\nbrowser and does not handle automation [33]. OpenWPM\nhas incorporated and expanded upon nearly all of Fourth-\nParty’s instrumentation (Section 3).'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='WebXray is a PhantomJS based tool for measuring HTTP\ntraﬃc [31]. It has been used to study third-party inclusions\non the top 1 million sites, but as we show in Section 3.3,\nmeasurements with a stripped-down browser have the po-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='traﬃc [31]. It has been used to study third-party inclusions\non the top 1 million sites, but as we show in Section 3.3,\nmeasurements with a stripped-down browser have the po-\ntential to miss a large number of resource loads.\nTrackingObserveris a Chrome extension that detects track-\ning and exposes APIs for extending its functionality such as\nmeasurement and blocking [48].\nXRay [27] and AdFisher [9] are tools for running auto-\nmated personalization detection experiments. AdFisher builds'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='on similar technologies as OpenWPM (Selenium, xvfb), but\nis not intended for tracking measurements.\nCommon Crawl 4 uses an Apache Nutch based crawler.\nThe Common Crawl dataset is the largest publicly available\nweb crawl5, with billions of page visits. However, the crawler\nused does not execute Javascript or other dynamic content\nduring a page visit. Privacy studies which use the dataset\n[49] will miss dynamically loaded content, which includes\nmany advertising resources.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='Crowd-sourcing of web privacy and personalization mea-\nsurement is an important alternative to automated brows-\ning. $heriﬀ and Bobble are two platforms for measuring per-\nsonalization [35, 65]. Two major challenges are participant\nprivacy and providing value to users to incentivize partici-\npation.\nPrevious ﬁndings. Krishnarmurthy and Wills [24] pro-\nvide much of the early insight into web tracking, showing the\ngrowth of the largest third-party organizations from 10% to'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='20-60% of top sites between 2005 and 2008. In the following\nyears, studies show a continual increase in third-party track-\ning and in the diversity of tracking techniques [33, 48, 20,\n2, 1, 4]. Lerner et al. also ﬁnd an increase in the prevalence\nand complexity of tracking, as well as an increase in the\ninterconnectedness of the ecosystem by analyzing Internet\nArchive data from 1996 to 2016 [29]. Fruchter et al. stud-\nied geographic variations in tracking [17]. More recently,'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='Libert studied third-party HTTP requests on the top 1 mil-\nlion sites [31], providing view of tracking across the web. In\nthis study, Libert showed that Google can track users across\nnearly 80% of sites through its various third-party domains.\nWeb tracking has expanded from simple HTTP cookies to\ninclude more persistent tracking techniques. Soltani et al.\nﬁrst examined the use of ﬂash cookies to “respawn” or re-\ninstantiate HTTP cookies [53], and Ayenson et al. showed'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='how sites were using cache E-Tags and HTML5 localStor-\nage for the same purpose [6]. These discoveries led to media\nbacklash [36, 30] and legal settlements [51, 10] against the\ncompanies participating in the practice. However several\nfollow up studies by other research groups conﬁrmed that,\ndespite a reduction in usage (particularly in the U.S.), the\ntechnique is still used for tracking [48, 34, 1].\nDevice ﬁngerprinting is a persistent tracking technique'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='which does not require a tracker to set any state in the user’s\n4https://commoncrawl.org\n5https://aws.amazon.com/public-data-sets/common-\ncrawl/'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 2, 'page_label': '3'}, page_content='browser. Instead, trackers attempt to identify users by a\ncombination of the device’s properties. Within samples of\nover 100,000 browsers, 80-90% of desktop and 81% of mobile\ndevice ﬁngerprints are unique [12, 26]. New ﬁngerprinting\ntechniques are continually discovered [37, 43, 16], and are\nsubsequently used to track users on the web [41, 2, 1]. In\nSection 6.1 we present several new ﬁngerprinting techniques\ndiscovered during our measurements.\nPersonalization measurement. Measurement of track-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 2, 'page_label': '3'}, page_content='ing is closely related to measurement of personalization,\nsince the question of what data is collected leads to the ques-\ntion of how that data is used. The primary purpose of online\ntracking is behavioral advertising — showing ads based on\nthe user’s past activity. Datta et al. highlight the incom-\npleteness of Google’s Ad Settings transparency page and\nprovide several empirical examples of discriminatory and\npredatory ads [9]. L´ ecuyer et al. develop XRay, a system'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 2, 'page_label': '3'}, page_content='for inferring which pieces of user data are used for personal-\nization [27]. Another system by some of the same authors is\nSunlight which improves upon their previous methodology\nto provide statistical conﬁdence of their targeting inferences\n[28].\nMany other practices that raise privacy or ethical con-\ncerns have been studied: price discrimination, where a site\nshows diﬀerent prices to diﬀerent consumers for the same\nproduct [19, 63]; steering, a gentler form of price discrimina-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 2, 'page_label': '3'}, page_content='tion where a product search shows diﬀerently-priced results\nfor diﬀerent users [32]; and the ﬁlter bubble , the supposed\neﬀect that occurs when online information systems person-\nalize what is shown to a user based on what the user viewed\nin the past [65].\nWeb security measurement. Web security studies of-\nten use similar methods as web privacy measurement, and\nthe boundary is not always clear. Yue and Wang modiﬁed\nthe Firefox browser source code in order to perform a mea-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 2, 'page_label': '3'}, page_content='surement of insecure Javascript implementations on the web\n[67]. Headless browsers have been used in many web security\nmeasurements, for example: to measure the amount of third-\nparty Javascript inclusions across many popular sites and\nthe vulnerabilities that arise from how the script is embed-\nded [40], to measure the presence of security seals on the top\n1 million sites [62], and to study stand-alone password gener-\nators and meters on the web [60]. Several studies have used'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 2, 'page_label': '3'}, page_content='Selenium-based frameworks, including: to measure and cat-\negorize malicious advertisements displayed while browsing\npopular sites [68], to measure the presence of malware and\nother vulnerabilities on live streaming websites [46], to study\nHSTS deployment [21], to measure ad-injecting browser ex-\ntensions [66], and to emulate users browsing malicious web\nshells with the goal of detecting client-side homephoning\n[55]. Other studies have analyzed Flash and Javascript el-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 2, 'page_label': '3'}, page_content='ements of webpages to measure security vulnerabilities and\nerror-prone implementations [42, 61].\n3. MEASUREMENT PLATFORM\nAn infrastructure for automated web privacy measure-\nment has three components: simulating users, recording ob-\nservations (response metadata, cookies, behavior of scripts,\netc.), and analysis. We set out to build a platform that\ncan automate the ﬁrst two components and can ease the\nresearcher’s analysis task. We sought to make OpenWPM\nT ask\nManager\nData\nAggregator\nWWW'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 2, 'page_label': '3'}, page_content='SeleniumBrowser\nManager Browser\n...\nBrowser\nManager Browser\nBrowser\nManager Browser\nInstrumentation Layer\nAnalysis\nScripts\nSelenium\nSelenium\nFigure 1: High-level overview of OpenWPM\nThe task manager monitors browser managers, which con-\nvert high-level commands into automated browser actions.\nThe data aggregator receives and pre-processes data from\ninstrumentation.\ngeneral, modular, and scalable enough to support essentially\nany privacy measurement.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 2, 'page_label': '3'}, page_content='OpenWPM is open source and has already been used for\nmeasurement by several published studies. Section 3.4 in'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 2, 'page_label': '3'}, page_content='general, modular, and scalable enough to support essentially\nany privacy measurement.\nOpenWPM is open source and has already been used for\nmeasurement by several published studies. Section 3.4 in\nthe supplementary materials examines the advanced features\nused by each study. In this paper we present, for the ﬁrst\ntime, the design and evaluation of the platform and highlight\nits strengths through several new measurements.\n3.1 Design Motivations\nOpenWPM builds on similar technologies as many previ-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 2, 'page_label': '3'}, page_content='ous platforms, but has several key design diﬀerences to sup-\nports modular, comprehensive, and maintainable measure-\nment. Our platform supports stateful measurements while\nFPDetective [2] does not. Stateful measurements are im-\nportant for studying the tracking ecosystem. Ad auctions\nmay vary based on cookie data. A stateless browser always\nappears to be a new user, which skews cookie syncing mea-\nsurements. In addition to cookie syncing studied in this'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 2, 'page_label': '3'}, page_content='paper, stateful measurements have allowed our platform to\nbe used to study cookie respawning [1] and replicate realistic\nuser proﬁles [14].\nMany past platforms rely on native instrumentation code\n[39, 52, 2], which have a high maintenance cost and, in some\ncases a high cost-per-API monitored. In our platform, the\ncost of monitoring new APIs is minimal (Section 3.3) and\nAPIs can be enabled or disabled in the add-on without re-\ncompiling the browser or rendering engine. This allows us to'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 2, 'page_label': '3'}, page_content='monitor a larger number of APIs. Native codebase changes\nin other platforms require constant merges as the upstream\ncodebase evolves and complete rewrites to support alterna-\ntive browsers.\n3.2 Design and Implementation\nWe divided our browser automation and data collection\ninfrastructure into three main modules: browser managers\nwhich act as an abstraction layer for automating individual\nbrowser instances, a user-facing task manager which serves'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 2, 'page_label': '3'}, page_content='to distribute commands to browser managers, and a data\naggregator, which acts as an abstraction layer for browser in-\nstrumentation. The researcher interacts with the task man-\nager via an extensible, high-level, domain-speciﬁc language\nfor crawling and controlling the browser instance. The entire\nplatform is built using Python and Python libraries.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 3, 'page_label': '4'}, page_content='Browser driver: Providing realism and support for\nweb technologies. We considered a variety of choices to\ndrive measurements, i.e., to instruct the browser to visit a set\nof pages (and possibly to perform a set of actions on each).\nThe two main categories to choose from are lightweight browsers\nlike PhantomJS (an implementation of WebKit), and full-\nﬂedged browsers like Firefox and Chrome. We chose to use\nSelenium, a cross-platform web driver for Firefox, Chrome,'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 3, 'page_label': '4'}, page_content='Internet Explorer, and PhantomJS. We currently use Sele-\nnium to drive Firefox, but Selenium’s support for multiple\nbrowsers makes it easy to transition to others in the future.\nBy using a consumer browser, all technologies that a typ-\nical user would have access to (e.g., HTML5 storage op-\ntions, Adobe Flash) are also supported by measurement\ninstances. The alternative, PhantomJS, does not support\nWebGL, HTML5 Audio and Video, CSS 3-D, and browser'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 3, 'page_label': '4'}, page_content='plugins (like Flash), making it impossible to run measure-\nments on the use of these technologies [45]. In retrospect\nthis has proved to be a sound choice. Without full support\nfor new web technologies we would not have been able to\ndiscover and measure the use of the AudioContext API for\ndevice ﬁngerprinting as discussed in Section 6.4.\nFinally the use of real browsers also allows us to test the\neﬀects of consumer browser extensions. We support run-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 3, 'page_label': '4'}, page_content='ning measurements with extensions such as Ghostery and\nHTTPS Everywhere as well as enabling Firefox privacy set-\ntings such third-party cookie blocking and the new Tracking\nProtection feature. New extensions can easily be supported\nwith only a few extra lines of code (Section 3.3). See Sec-\ntion 5.3 and Section 5.5 for analyses of measurements run\nwith these browser settings.\nBrowser managers: Providing stability. During the\ncourse of a long measurement, a variety of unpredictable'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 3, 'page_label': '4'}, page_content='events such as page timeouts or browser crashes could halt\nthe measurement’s progress or cause data loss or corruption.\nA key disadvantage of Selenium is that it frequently hangs\nindeﬁnitely due to its blocking API [50], as it was designed to\nbe a tool for webmasters to test their own sites rather than\nan engine for large-scale measurements. Browser managers\nprovide an abstraction layer around Selenium, isolating it\nfrom the rest of the components.'),
# ...
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 17, 'page_label': '18'}, page_content='any domain’s cookie sync API or URL pattern. An im-\nportant limitation of this generic approach is the lack of\ndiscrimination between intentional cookie syncing and acci-\ndental ID sharing. The latter can occur if a site includes a\nuser’s ID within its URL query string, causing the ID to be\nshared with all third parties in the referring URL.\nThe results of this analysis thus provide an accurate rep-\nresentation of the privacy implications of ID sharing, as a'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 17, 'page_label': '18'}, page_content='third party has the technical capability to use an uninten-\ntionally shared ID for any purpose, including tracking the\nuser or sharing data. However, the results should be in-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 17, 'page_label': '18'}, page_content='third party has the technical capability to use an uninten-\ntionally shared ID for any purpose, including tracking the\nuser or sharing data. However, the results should be in-\nterpreted only as an upper bound on cookie syncing as the\npractice is deﬁned in the online advertising industry.\n13.4 Detection of Fingerprinting\nJavascript miniﬁcation and obfuscation hinder static anal-\nysis. Miniﬁcation is used to reduce the size of a ﬁle for tran-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 17, 'page_label': '18'}, page_content='sit. Obfuscation stores the script in one or more obfuscated\nstrings, which are transformed and evaluated at run time\nusing eval function. We ﬁnd that ﬁngerprinting and track-\ning scripts are frequently miniﬁed or obfuscated, hence our\ndynamic approach. With our detection methodology, we\nintercept and record access to speciﬁc Javascript objects,\nwhich is not aﬀected by miniﬁcation or obfuscation of the\nsource code.\nThe methodology builds on that used by Acar, et.al. [1]'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 17, 'page_label': '18'}, page_content='to detect canvas ﬁngerprinting. Using the Javascript calls\ninstrumentation described in Section 3.2, we record access\nto speciﬁc APIs which have been found to be used to ﬁn-\ngerprint the browser. Each time an instrumented object is\naccessed, we record the full context of the access: the URL\nof the calling script, the top-level url of the site, the prop-\nerty and method being accessed, any provided arguments,\nand any properties set or returned. For each ﬁngerprint-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 17, 'page_label': '18'}, page_content='ing method, we design a detection algorithm which takes\nthe context as input and returns a binary classiﬁcation of\nwhether or not a script uses that method of ﬁngerprinting\nwhen embedded on that ﬁrst-party site.\nWhen manual veriﬁcation is necessary, we have two ap-\nproaches which depend on the level of script obfuscation. If\nthe script is not obfuscated we manually inspect the copy\nwhich was archived according to the procedure discussed in'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 17, 'page_label': '18'}, page_content='Section 3.2. If the script is obfuscated beyond inspection, we\nembed a copy of the script in isolation on a dummy HTML\npage and inspect it using the Firefox Javascript Deobfusca-\ntor20 extension. We also occasionally spot check live versions\nof sites and scripts, falling back to the archive when there\nare discrepancies.\n20https://addons.mozilla.org/en-US/ﬁrefox/addon/\njavascript-deobfuscator/'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 18, 'page_label': '19'}, page_content='Fingerprinting Script Count\ncdn.doubleverify.com/dvtp src internal24.js 4588\ncdn.doubleverify.com/dvtp src internal23.js 2963\nap.lijit.com/sync 2653\ncdn.doubleverify.com/dvbs src.js 2093\nrtbcdn.doubleverify.com/bsredirect5.js 1208\ng.alicdn.com/alilog/mlog/aplus v2.js 894\nstatic.audienceinsights.net/t.js 498\nstatic.boo-box.com/javascripts/embed.js 303\nadmicro1.vcmedia.vn/core/ﬁpmin.js 180\nc.imedia.cz/js/script.js 173\nap.lijit.com/www/delivery/fp 140\nwww.lijit.com/delivery/fp 127'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 18, 'page_label': '19'}, page_content='s3-ap-southeast-1.amazonaws.com/af-bdaz/bquery.js 118\nd38nbbai6u794i.cloudfront.net/*/platform.min.js 97\nvoken.eyereturn.com/ 85\np8h7t6p2.map2.ssl.hwcdn.net/fp/Scripts/PixelBundle.js 72\nstatic.fraudmetrix.cn/fm.js 71\ne.e701.net/cpc/js/common.js 56\ntags.bkrtx.com/js/bk-coretag.js 56\ndtt617kogtcso.cloudfront.net/sauce.min.js 55\n685 others 1853\nTOTAL\n18283\n14371 unique1\nTable 11: Canvas ﬁngerprinting scripts on the top Alexa 1 Million sites.\n**: Some URLs are truncated for brevity.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 18, 'page_label': '19'}, page_content='1: Some sites include ﬁngerprinting scripts from more than one domain.\nFingerprinting script # of sites Text drawn into the canvas\nmathid.mathtag.com/device/id.js\nmathid.mathtag.com/d/i.js 2941 mmmmmmmmmmlli\nadmicro1.vcmedia.vn/core/ﬁpmin.js 243 abcdefghijklmnopqr[snip]\n*.online-metrix.net1 75 gMcdefghijklmnopqrstuvwxyz0123456789\npixel.infernotions.com/pixel/ 2 mmmmmmmmmMMMMMMMMM=llllIiiiiii‘’.\napi.twisto.cz/v2/proxy/test* 1 mmmmmmmmmmlli\ngo.lynxbroker.de/eat session.js 1 mimimimimimimi[snip]'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 18, 'page_label': '19'}, page_content='TOTAL\n3263\n(3250 unique2) -\nTable 12: Canvas font ﬁngerprinting scripts on the top Alexa 1 Million sites.\n**: Some URLs are truncated for brevity.\n1: The majority of these inclusions were as subdomain of the ﬁrst-party site, where the DNS record points to a subdomain\nof online-metrix.net.\n2: Some sites include ﬁngerprinting scripts from more than one domain.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 19, 'page_label': '20'}, page_content='Fingerprinting Script First-party Count Classiﬁcation\ncdn.augur.io/augur.min.js 147 Tracking\nclick.sabavision.com/*/jsEngine.js 115 Tracking\nstatic.fraudmetrix.cn/fm.js 72 Tracking\n*.hwcdn.net/fp/Scripts/PixelBundle.js 72 Tracking\nwww.cdn-net.com/cc.js 45 Tracking\nscripts.poll-maker.com/3012/scpolls.js 45 Tracking\nstatic-hw.xvideos.com/vote/displayFlash.js 31 Non-Tracking\ng.alicdn.com/security/umscript/3.0.11/um.js 27 Tracking\nload.instinctiveads.com/s/js/afp.js 16 Tracking'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 19, 'page_label': '20'}, page_content='cdn4.forter.com/script.js 15 Tracking\nsocauth.privatbank.ua/cp/handler.html 14 Tracking\nretailautomata.com/ralib/magento/raa.js 6 Unknown\nlive.activeconversion.com/ac.js 6 Tracking\nolui2.fs.ml.com/publish/ClientLoginUI/HTML/cc.js 3 Tracking\ncdn.geocomply.com/101/gc-html5.js 3 Tracking\nretailautomata.com/ralib/shopifynew/raa.js 2 Unknown\n2nyan.org/animal/ 2 Unknown\npixel.infernotions.com/pixel/ 2 Tracking\n167.88.10.122/ralib/magento/raa.js 2 Unknown\n80 others present on a single ﬁrst-party 80 -'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 19, 'page_label': '20'}, page_content='TOTAL 705 -\nTable 13: WebRTC Local IP discovery on the Top Alexa 1 Million sites.\n**: Some URLs are truncated for brevity.\nSite Prominence # of FP Rank Change\ndoubleclick.net 6.72 447,963 +2\ngoogle-analytics.com 6.20 609,640 −1\ngstatic.com 5.70 461,215 −1\ngoogle.com 5.57 397,246 0\nfacebook.com 4.20 309,159 +1\ngooglesyndication.com 3.27 176,604 +3\nfacebook.net 3.02 233,435 0\ngoogleadservices.com 2.76 133,391 +4\nfonts.googleapis.com 2.68 370,385 −4\nscorecardresearch.com 2.37 59,723 +13'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 19, 'page_label': '20'}, page_content='adnxs.com 2.37 94,281 +2\ntwitter.com 2.11 143,095 −1\nfbcdn.net 2.00 172,234 −3\najax.googleapis.com 1.84 210,354 −6\nyahoo.com 1.83 71,725 +5\nrubiconproject.com 1.63 45,333 +17\nopenx.net 1.60 59,613 +7\ngoogletagservices.com 1.52 39,673 +24\nmathtag.com 1.45 81,118 −3\nadvertising.com 1.45 49,080 +9\nTable 14: Top 20 third-parties on the Alexa top 1 million, sorted by prominence. The number of ﬁrst-party sites'),
#  Document(metadata={'producer': 'pdfTeX-1.40.16', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'page': 19, 'page_label': '20'}, page_content='each third-party is embedded on is included. Rank change denotes the change in rank between third-parties ordered\nby ﬁrst-party count and third-parties ordered by prominence.')]

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# выбираем модель для создания эмбеддингов
model_name = 'jhgan/ko-sroberta-multitask'
model_kwargs = {'device': 'cpu'}
encode_kwargs = {'normalize_embeddings': False}

embedding_model = HuggingFaceEmbeddings(
  model_name=model_name,
  model_kwargs=model_kwargs,
  encode_kwargs=encode_kwargs
)

# %%
from langchain_chroma import Chroma

# инициализируем векторную базу
db = Chroma.from_documents(documents=splits, embedding=embedding_model)

# %%
# выполняем тестовый запрос!
query = 'third party'
docs = db.similarity_search(query)

for idx, doc in enumerate(docs):
  print(idx, doc)
# Out:
# 0 page_content='third party has the technical capability to use an uninten-
# tionally shared ID for any purpose, including tracking the
# user or sharing data. However, the results should be in-' metadata={'subject': '', 'moddate': '2016-10-25T21:39:52+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'author': '', 'creationdate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'page': 17, 'total_pages': 20, 'title': '', 'creator': 'LaTeX with hyperref package', 'keywords': '', 'page_label': '18', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'producer': 'pdfTeX-1.40.16'}
# 1 page_content='third party has the technical capability to use an uninten-
# tionally shared ID for any purpose, including tracking the
# user or sharing data. However, the results should be in-' metadata={'keywords': '', 'page_label': '18', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'subject': '', 'page': 17, 'author': '', 'title': '', 'producer': 'pdfTeX-1.40.16', 'total_pages': 20, 'creationdate': '2016-10-25T21:39:52+00:00', 'creator': 'LaTeX with hyperref package', 'moddate': '2016-10-25T21:39:52+00:00'}
# 2 page_content='third party has the technical capability to use an uninten-
# tionally shared ID for any purpose, including tracking the
# user or sharing data. However, the results should be in-' metadata={'keywords': '', 'title': '', 'creator': 'LaTeX with hyperref package', 'creationdate': '2016-10-25T21:39:52+00:00', 'author': '', 'page_label': '18', 'producer': 'pdfTeX-1.40.16', 'page': 17, 'trapped': '/False', 'total_pages': 20, 'subject': '', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'moddate': '2016-10-25T21:39:52+00:00', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf'}
# 3 page_content='Figure 3: Organizations with the highest third-party pres-
# ence on the top 1 million sites. Not all third parties are clas-
# siﬁed as trackers, and in fact the same third party can be
# classiﬁed diﬀerently depending on the context. (Section 4).
# Larger entities may be easier to regulate by public-relations
# pressure and the possibility of legal or enforcement actions,
# an outcome we have seen in past studies [1, 6, 34].' metadata={'title': '', 'creationdate': '2016-10-25T21:39:52+00:00', 'producer': 'pdfTeX-1.40.16', 'subject': '', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'author': '', 'total_pages': 20, 'page': 7, 'moddate': '2016-10-25T21:39:52+00:00', 'page_label': '8', 'creator': 'LaTeX with hyperref package', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'keywords': '', 'trapped': '/False'}

# %%
# выполняем тестовый запрос со скорингом!
query = 'third party'
docs = db.similarity_search_with_score(query)

print(query)

for idx, doc in enumerate(docs):
  print(idx, doc[-1], doc)

docs = [doc[0] for doc in docs]
# Out:
# third party
# 0 88.93215942382812 (Document(id='bc921521-ab35-475e-bb8e-f2f96990d9cb', metadata={'subject': '', 'page': 17, 'producer': 'pdfTeX-1.40.16', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'creationdate': '2016-10-25T21:39:52+00:00', 'keywords': '', 'total_pages': 20, 'author': '', 'creator': 'LaTeX with hyperref package', 'title': '', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'trapped': '/False', 'page_label': '18', 'moddate': '2016-10-25T21:39:52+00:00'}, page_content='third party has the technical capability to use an uninten-\ntionally shared ID for any purpose, including tracking the\nuser or sharing data. However, the results should be in-'), 88.93215942382812)
# 1 88.93215942382812 (Document(id='63408adc-6744-4ec8-833b-93aeb2461769', metadata={'subject': '', 'page_label': '18', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'creationdate': '2016-10-25T21:39:52+00:00', 'total_pages': 20, 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'author': '', 'keywords': '', 'trapped': '/False', 'producer': 'pdfTeX-1.40.16', 'title': '', 'moddate': '2016-10-25T21:39:52+00:00', 'page': 17, 'creator': 'LaTeX with hyperref package'}, page_content='third party has the technical capability to use an uninten-\ntionally shared ID for any purpose, including tracking the\nuser or sharing data. However, the results should be in-'), 88.93215942382812)
# 2 88.93215942382812 (Document(id='2305f751-a2e8-4fa0-b1db-1b6b2028a3cd', metadata={'moddate': '2016-10-25T21:39:52+00:00', 'subject': '', 'page_label': '18', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'total_pages': 20, 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'creationdate': '2016-10-25T21:39:52+00:00', 'trapped': '/False', 'creator': 'LaTeX with hyperref package', 'page': 17, 'title': '', 'author': '', 'producer': 'pdfTeX-1.40.16', 'keywords': ''}, page_content='third party has the technical capability to use an uninten-\ntionally shared ID for any purpose, including tracking the\nuser or sharing data. However, the results should be in-'), 88.93215942382812)
# 3 91.44871520996094 (Document(id='bc028ebe-0d71-4c43-8e25-712c1d2530b5', metadata={'page_label': '8', 'page': 7, 'author': '', 'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf', 'keywords': '', 'trapped': '/False', 'moddate': '2016-10-25T21:39:52+00:00', 'creator': 'LaTeX with hyperref package', 'total_pages': 20, 'creationdate': '2016-10-25T21:39:52+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'subject': '', 'producer': 'pdfTeX-1.40.16', 'title': ''}, page_content='Figure 3: Organizations with the highest third-party pres-\nence on the top 1 million sites. Not all third parties are clas-\nsiﬁed as trackers, and in fact the same third party can be\nclassiﬁed diﬀerently depending on the context. (Section 4).\nLarger entities may be easier to regulate by public-relations\npressure and the possibility of legal or enforcement actions,\nan outcome we have seen in past studies [1, 6, 34].'), 91.44871520996094)

# %% [markdown]
# ### ChromaDB

# %%
# запись базы на диск
Chroma.from_documents(docs, embedding_model, persist_directory='./chroma_db')

# %%
# чтение с диска
Chroma(persist_directory='./chroma_db', embedding_function=embedding_model)

# %%
from uuid import uuid4

example_db = Chroma.from_documents(docs, embedding_model, ids=[str(uuid4()) for doc in docs])

# %%
example_db._collection.count()
# Out:
# 526

# %%
example_db.get()
# Out:
# {'ids': ['28fcc4d9-52cf-47b8-b450-c07123dd2e22',
#   '5553cb5d-535f-4f72-b6ff-26928fe1ce29',
#   'db766cdb-7a09-4069-8a2f-705284eeea08',
#   'e16f4ccf-55e7-415e-9bf6-defcd09443a2',
#   'cd5c59f1-7e82-4624-b6af-72b60063dd5e',
#   '69c6aedf-9b98-4898-ad72-a0165813a659',
#   'cf2afed5-0ac0-4d3c-8f3a-5eff44cf528e',
#   'a05dca08-f68d-4f61-804b-725d4d48bf8c',
#   '66cdbc72-d7bd-49e2-b95a-cd422f5e73ba',
#   '287eb321-657f-4345-907c-3a4622ecb8cc',
#   'f1bb2baa-cf28-426b-9be2-f85838035b4c',
#   '8540bfb5-173b-4d45-8f85-34da14420b17',
#   '9eee0451-7fa8-4727-b9a4-8b1fc235cb6d',
#   '5715ffdb-1779-4fd5-b34d-faf9a34c777a',
#   '5758e987-b21a-4846-b874-6439704f05e5',
#   '09dac63b-b80e-4309-8c88-b75ea075c20c',
#   'bf97a19d-37e9-4b2a-b17d-438bd29158c1',
#   '9afbd89b-974d-4975-a500-5049423fcc3a',
#   '61f707cb-7861-45b1-885f-5f3e018d9b9c',
#   '84b6832a-71d0-4555-a2b7-0af6931d2d77',
#   '648cbe64-80fd-4741-9f7c-6059b2b1d172',
#   '8f0756d3-7164-4b14-8fe9-414823b0cee8',
#   'ca3c5b99-1f60-4c21-af80-ed7e82818507',
#   'c9d5c11d-057c-4629-8eed-7c3e09e4e80b',
#   '39bf636c-5603-4f86-84c4-33cb3199454b',
#   'ed3fa14e-1c83-4d96-8967-b7994397d6f3',
#   'e8e7b71e-a32e-44e2-bd55-6bd3b3964a10',
#   'ababb773-c668-4aa6-9385-b5f50653e811',
#   'c79678ce-c11e-49f3-ba1a-15688a993a04',
#   'e7a9567d-e4dc-46c2-9f0b-53311e1cab44',
#   '7e2c7b24-c9f8-44a8-9765-ea775e2b60af',
#   '2cc63602-0854-449d-a159-ecad7db9dadb',
#   '4ff56915-cab1-4d32-b989-f3637247fc55',
#   'ee0138ca-7f8c-463c-9332-51f62612cc72',
#   '7bbed4ff-dd1f-494a-960d-a7faa86bcb3c',
#   '5f3d6069-cc88-4597-9c4b-7530a0de8e1a',
#   '7b7bde1c-c118-4cb8-a0c8-c03d171481b5',
#   '2f8a6dc3-e3e1-4dc3-b197-8f92671908bb',
#   'bfd970f3-5327-4241-b796-8a5e9f4a13af',
#   '32063781-d111-4d41-90b8-f78e1702d88e',
#   '5e6803be-54a3-4ace-8225-ce94d1505d63',
#   '95301b65-c8dd-4cb9-821c-896082442853',
#   '49264afd-f118-4b44-ad46-a00e3540a080',
#   'e1d7ef79-5f36-4dea-8338-7f76ccf8ce4b',
#   '2bd1863a-487e-430c-8e68-4ddc90c60662',
#   'a6b41349-6ac1-4e77-9699-28c00d01fea2',
#   '74a8c87c-87a4-4917-832f-404fd5ad7dfe',
#   'c2b58448-c26d-4765-bc48-0827b2d15f34',
#   '023b86be-1b84-46a1-b164-9012b4ded6db',
#   '10c8a4fa-0097-4623-a48d-6c1736459c2f',
#   '1030ee69-0543-4cd6-bbf5-0cae8ab0f9ff',
#   'efe8f64a-57a3-4442-ad13-00bf8c1258cf',
#   'b3d26b14-d600-4551-96cb-5baf8c44ad8a',
#   'e0a55825-5796-4ca4-beea-7c365e3254db',
#   '5033f408-0269-4021-8ef9-b1dd75eeeb5e',
#   'eba7200a-e416-4191-85c5-2db5583764ed',
#   'adb27110-5e4b-4243-a162-e358d1846560',
#   '4c69cf20-b03e-43e0-85ae-e917c5a8a6da',
#   '461fd17d-9a80-468b-b742-f0998fdc0304',
#   '5d4f239e-223d-431a-b063-8d582da314f9',
#   '8453b429-ae19-451e-88da-d38c03d4b282',
#   '5838833a-61f0-481e-816b-4bf6d7a3cf23',
#   'a3dcf103-a0f6-4534-aef0-dcd33a4e178a',
#   '3fdc13de-5dd3-4ef5-af13-01a42e0348f6',
#   '52e11ba6-64ac-455d-8f2f-f7e597cde584',
#   'c001c63a-b611-431f-89ba-cd0f7dd0568f',
#   'f6c2afd0-c74a-48b8-878e-95ca7f08a245',
#   '38633be1-280d-425e-be2a-a9fe8dabec17',
#   '17cf9420-12ee-4ae8-9de6-bedb289217d7',
#   '0096bf54-f59c-4212-a6b2-db5fc9f26fa8',
#   'cf37d5b2-d270-4ad0-aa47-c27fc50cb25a',
#   'e40dc8d5-20e2-4b31-83c0-2ac53d10b21d',
#   '0c0cc78d-f046-4d2b-bd52-0cd41950b133',
#   '93376e53-dfd5-40f4-8fe6-0b11fbd37308',
#   'f6dd7f3b-c9f5-4e76-8f3f-2a4b9db61ebe',
#   'a8f8ec2d-c295-4447-9568-1e653e6bf79b',
#   'f14cc6b7-6cb9-4c6e-bcc8-a530034ebc71',
#   '774cf72a-d306-415a-9ffb-1080709c3d9c',
#   '1c93d58d-7bdc-48a3-8393-91283743b518',
#   'e1b47105-e421-41cd-a4c3-1c162ca3b282',
#   '49d4df0c-9a5e-47ce-b190-88aff325e9de',
#   'dda27514-1e62-4dbb-a60a-610e760b47cd',
#   'e2a93390-0fcc-48c9-ab81-305ba9b8902e',
#   'b16e42fb-649c-4b02-be48-53369d8b34b7',
#   '9428b303-ba14-46a7-9a52-4661c5037c59',
#   'ea8faaed-50b5-4bed-bd21-63d31ed77f4f',
#   'e53c2e66-5a06-4c16-98ad-2d846359c8ee',
#   '5844a487-dfa8-401f-8d4b-3c9ff4af0565',
#   'fd1d569b-83d9-436c-b640-93d9f524ae5d',
#   '6d3c8219-7338-47e7-a536-89a11d36ae65',
#   '53b41740-e787-4267-b88d-5da32d9c58cb',
#   '55039978-0d49-4436-94f1-872eb3a5a72c',
#   '50f18645-51cd-4c63-af30-588c9bcae27f',
#   'd0bbaf49-d72a-4b46-a647-40528a3be9e5',
#   '381fecf8-12d2-4ea3-ad00-0c38de76d31c',
#   '03727787-ec2b-4c33-8608-12dc75520d02',
#   '406666fb-a3a1-4d08-8a52-0daaa8ca55e1',
#   '5b7a9c54-68e0-4027-a626-269dd3fc59f5',
#   '0de12a1c-57ef-4e4e-8fcc-55f1f4ffcd7c',
#   '224273db-0326-4fcf-a82d-00174ee5b812',
#   '2cc35c78-0f68-4be8-b6d9-aedb87fd6c54',
#   'd248cc75-8fa1-4625-b9ef-c5c3e230a4c9',
#   'db8a5bd2-4c90-4dd1-9714-4cc1b853652c',
#   '7042ae18-78cb-4fb2-b669-73f01b6beeca',
#   'e274a128-518b-4da3-9408-8cff2b65b1c5',
#   'd2412601-6b54-47b6-a73c-e87d2990cfb0',
#   '90f95e98-a19a-4d9b-9840-e6136a6e5dad',
#   'f80fc79f-22d1-41c6-a4ba-bdf770503fda',
#   'd33edb86-170d-4d89-aae7-64d0450912fe',
#   '0bba00d5-ac3c-4762-915b-805ec77ab35b',
#   '665c5863-3383-488f-8741-2882fe2270f8',
#   'a8a065fc-beec-43a8-9c85-748ececef3ca',
#   '903d6a2f-f0d8-4cb6-862d-515308b7af4c',
#   '2bd83f7b-ed87-4d94-8c24-2f42c521e242',
#   '3fcd384f-0dfe-4361-b140-3210f38d61a4',
#   'c497a7e5-7773-433b-b9e0-d64788de99eb',
#   'ff9d9c4c-0b1f-4c60-968c-81af1a51d6fb',
#   '587986b3-fdae-4786-919f-db4cc95ef5b5',
#   '9978dcf8-848b-446f-a110-b779e23ee27e',
#   '24985bcc-1c18-4c21-b2c0-ed20a61f2e9c',
#   '4a10c738-d87a-495d-aeae-8ed1980208d9',
#   'c83308d0-10c2-4f7d-951e-9432a9cb1a5c',
#   '913092f9-83ae-4054-b990-28dbdeb79f99',
#   '4f24d211-5219-4fac-9497-346d1f61c5e2',
#   '2294f2db-c3c2-4038-896a-2b66e4c53462',
#   'e5bca6e3-56f1-421f-bb4c-5231cf85e943',
#   '1574fcbf-35af-4362-90ad-54fc39f12fda',
#   '582d780a-7901-445f-99f1-ae919b15129f',
#   '460a4df8-4558-4f7b-8434-a9e18df6f650',
#   '70f22a02-3bea-435c-bbe5-cad2b53bcf38',
#   'f369bdbd-34ca-4587-b373-50aa7829105a',
#   'c411bb27-d504-44d0-b60b-9535e63f9a24',
#   '3acb26a6-013e-4b50-9f69-a24ad5cc95bd',
#   '35640a99-9627-412e-ae43-698fb896ced4',
#   '3f5c9c52-8834-442c-a8f8-1934eed22411',
#   '256f137e-f31a-4094-a900-ad50173f075d',
#   'fcfc0e76-4583-4b33-bc5f-f767c229a6c4',
#   'aa29d4fc-33ce-4ec9-a20c-8279654b0544',
#   '6ab9a7a1-d9a1-4bbf-a8d0-37fe92964b15',
#   'ac7e46c5-5b96-44cd-b370-8ffae96aa3e0',
#   'e59e76d7-a129-421e-8f15-bdf08869937d',
#   'cc856e6a-defd-41b5-838c-f89ebacef8ea',
#   '956100d4-9135-4144-8289-825be4ebe64e',
#   'fd101695-18fe-42f8-a555-a38292204d20',
#   'ed38893e-cf24-40ed-93f0-ce7beff59935',
#   'ed0a8ba0-c368-47af-b92f-d93452b724e5',
#   '6d524003-b460-427e-82bf-75d044a94938',
#   'ad616c34-a0b7-4548-ab9c-b62a53856d53',
#   '3f468aab-d31c-485c-ac5b-ab43e26aebec',
#   '2c593f82-b4b4-4e44-a696-a8e96530b158',
#   'e26775f1-ca10-4b88-a221-09ce7280ba6e',
#   '221dde23-64d7-4de3-a59d-4d4868d7e7f5',
#   '8b9b0bd6-237a-4a59-8fe8-3790f0f69922',
#   '8d7c96ca-cb07-4c3f-a4fa-620d4bb13b05',
#   '070138e7-1067-4bc8-94cc-c888f3b50293',
#   'bff09660-eb29-4b3b-9e51-ad73c9dea2fe',
#   '5cb07944-39f7-4eed-a9b9-ceecda42ef91',
#   'c3ffc0c5-b844-4730-b7f6-a014fd6fa4ee',
#   '5c555ecf-922a-494f-807b-1b9cacb42d53',
#   'a11ab4b0-b367-4bf4-a28d-4a62d51fcf78',
#   '8eeff255-3a50-457a-86ea-5839a3125a3b',
#   'b6848a8e-5265-4620-9137-fc42118443ee',
#   '804bd7a6-920e-47f8-82e7-50da0603465e',
#   '7dbb8051-ac61-4ff1-9464-0e2e674a5bed',
#   '39f231ef-6b34-4d4d-8203-5a184d9ca4d6',
#   '30ddd6ba-6024-4a7b-a8c7-94943941be5f',
#   'fd40696d-6bd9-41cf-b20c-29a9102b9e2d',
#   'a15ac054-c094-4b45-b1d6-e5b70bdef5a1',
#   'effdcce4-ac51-427b-ac31-198a9f8558b0',
#   'dfd66dbf-cade-42e0-b132-4739c1074cf9',
#   '6af0a94d-5135-4ba0-a5c2-2bc0823fb50e',
#   'fc4cd45a-dbb5-4fa5-9c0a-bf4702535fea',
#   '3d35b5e3-74e6-4a27-8709-8df278ae96f2',
#   '7e21ca80-8f9f-4623-a7b4-d47f6d7cae17',
#   'fb14be4e-3c45-4c92-ab18-4bd2163afd99',
#   '4cdaba6e-20f8-4c06-a477-4c310377f376',
#   '4bdbd007-b5bf-4a46-b3e6-42a570ec7434',
#   '7d7b2c46-4414-4026-a1f2-64378efb6676',
#   '4a56226d-44a6-4aff-bd37-06b587fc3df8',
#   '43a89e86-fb42-4556-b692-1e47948f0349',
#   '1c876e6d-278b-4e6d-ac5a-d08d80473e96',
#   'e27bc909-bfa3-47d9-bfe5-6995ce829453',
#   '646887f6-4a7f-473b-964f-039269b7ecc6',
#   'd4400e4b-17e9-48f6-8e6a-1dcfa6630c50',
#   'b1adea29-5dc7-4af1-ac66-517e6c463aba',
#   '4c4ffea0-4fb9-4de7-99fa-b3185ef008b3',
#   '2db65d56-9a9b-4153-8501-6419d2dde10e',
#   '8b9e9134-b749-4e35-893c-c77f11429956',
#   '616238f6-7b2c-4e97-a42d-43b3415aaaa5',
#   'dac3c14d-5409-4074-ad3b-e172e37c5ac5',
#   '1aeb1bfe-29c9-4eeb-be27-4dde019e26ea',
#   '0948b738-329a-4216-a72b-8712231c2816',
#   'a9df6e74-9395-463e-88a6-06bc3e15e5aa',
#   '23c13800-f744-453d-a68f-571da5ad8b1a',
#   '05d21bfe-8294-4873-be3c-002509e17f3c',
#   'a2dac0be-662d-4cbb-a28d-d6c407c95130',
#   '5950cd04-dd1b-43d3-852b-388fead1854a',
#   'dc2ed8ab-d7fe-4233-a4f7-e4165b676381',
#   'd6cea5df-511f-4fa5-b1e5-d47805435a04',
#   'f43e3270-5feb-466e-bdc5-4f4df35713a8',
#   '6eb9329e-288c-402c-94ff-590dbf088d1a',
#   'eed725e6-e8ae-4ea7-bf4b-96ca68a268bd',
#   '86e435b5-1d6b-4658-b759-e160ffba252c',
#   'a7e8522f-2621-40a4-8b52-083131712bb8',
#   'eb1fe422-8ba3-4a1f-bd68-94940cb0db9c',
#   '0e21d5a4-a947-465c-bef5-161bfdf73646',
#   'b3a8ad4f-a730-4fce-9e3e-8dccb659c896',
#   '5d6b7711-9651-4c1b-9cc2-e71da059f021',
#   '4b139f24-9bd4-449b-940c-2485d816daea',
#   '90893d19-0f52-453e-bc4d-53602c7a8123',
#   'd61e92d8-cee1-46c9-a705-ab85247c18ef',
#   'e6588f9b-6f6f-473f-a97d-29052e1a5dad',
#   '221119d4-69dc-4127-9f27-598382a8261e',
#   'e63dae85-8296-47cd-b807-e3cbf088200d',
#   '3d8e658d-a4ab-413f-b431-2cfbba04b800',
#   'ae4adfaf-1db2-461d-9059-6813d1aaac28',
#   'b0dcc6c2-7c74-4822-baf5-2a4c0d4e3987',
#   'c9f13263-27ae-41c7-8a62-1487fa0ff647',
#   '1bc33611-8ec0-44c3-ba72-4f1499253694',
#   '5c17ee88-124c-4d05-b9d9-54465ba639f1',
#   '04d75596-4f15-48d4-ae8f-796b99bd9027',
#   '15f91340-3802-4bbd-adee-90d184492f31',
#   'a2fda438-0043-4e0c-b2fe-499b72e83879',
#   '128c99e9-fb69-4f45-b0c2-ab87c9a17936',
#   '13217b2a-86a5-4a5c-a4c6-4f69029a4634',
#   'bde69b4c-1140-4dea-aeda-39496618c20a',
#   'f35423f2-08c8-4f29-96b3-71327a97cebf',
#   'fec1f6cc-6fca-4400-a006-39d3501c62b9',
#   '312304cf-caff-49da-b330-79a7e4100acd',
#   '77f17aad-4d92-4a8a-adaf-540f58e9cece',
#   '57101b43-eff5-4b0e-8d0d-4705676cb135',
#   'e51d6382-c3be-408d-a628-d365d48b0791',
#   'c5f0c444-06e1-49ab-9c19-db12186c3c6b',
#   '3ebe8870-c95e-4ca5-84d4-dded85855411',
#   '21dd0c0e-d8a2-43f1-8d4f-e43adb3503e6',
#   '109ccd95-9216-4408-ab40-156e7a6293af',
#   '645e0be9-c0fc-412b-8142-548aae5ae654',
#   '2969721b-39b4-459f-b077-d40e826690c5',
#   '7b1838b5-ab73-4816-9f0a-86e299f8a9a9',
#   'd08aa168-790b-436f-9bd3-dc6a1cf29aa0',
#   '57566852-358f-4c2b-b72a-17798b136aea',
#   'fcb48583-6807-4662-b97d-a3e0b6fd6151',
#   '152547cc-50a2-47db-aa9c-5ba6cbd7631d',
#   '504eff6f-a53f-4cbf-ad98-cb048e999066',
#   'bc921521-ab35-475e-bb8e-f2f96990d9cb',
#   'b1be0ae7-430c-4c63-aaa4-14f746da0513',
#   '358c147d-f7dc-4d1f-a20d-b24e88e03a8c',
#   '700341dc-dd3e-4187-ab97-dc466e263141',
#   'c301d065-2b18-4ef9-881f-286956f7ffce',
#   'dcab63a0-5a3d-490f-9e4a-09747507fc9c',
#   'c2cb1443-5c08-4e0c-81fc-8163f38d1ffa',
#   '18b7e508-e29e-4e60-9289-f2100e201b6d',
#   '1d385fe4-f566-456a-974e-8007967c4809',
#   '44898edb-4ff0-479d-a313-98307088213f',
#   '13b0441e-0214-49ff-9ab7-b3ffb36a788b',
#   'd23c303f-5b6d-4c1e-a7f1-7424c6eab19c',
#   '45be34a5-1d00-4371-8657-28aed5ec10e3',
#   '06481cf5-59b5-4a06-b51c-c34f173742e9',
#   '00e4aa6e-f594-44e6-89de-fecd9756a183',
#   '63408adc-6744-4ec8-833b-93aeb2461769',
#   '481c4761-f367-4725-8ca8-7acfddeb45cb',
#   '5ed14bfe-2d06-4a99-a4e6-ff145d841d1b',
#   'c6596009-2355-43bc-a162-463ed855b025',
#   '410cd343-5b76-4df4-bda4-889b69d4aaf6',
#   '3caaf679-c7d4-4e42-bcd4-e5c418181496',
#   '051b1f13-190a-4b45-ae98-9a47488dc520',
#   '10e631e5-53f9-4925-8835-425059f6eaef',
#   'c89fe502-d404-48be-a298-74c6c148784e',
#   '50b4ad80-d5b4-4bf6-a70b-c0ccc8177cf2',
#   'fd7746cf-4c7b-402f-b5c7-ce8afa907b94',
#   '28b33d38-bd31-42a3-a954-34f2864ee1c0',
#   '3a41ee8b-2844-4a1b-bacc-3450f96c6c72',
#   'fbbd0b4f-ce65-45ec-b41d-cd607aa4a06c',
#   '5cbaa284-b5c0-4bb3-ae2f-1f23f4ce2558',
#   '112c9c8b-d574-44b1-9ffe-aece8da4417d',
#   '179b621f-3b3b-4576-8224-49fdae137fef',
#   '21f8cd2f-a72b-4da6-8c2f-5ba72b996f4c',
#   '78103d94-d135-4831-80f3-816756d2fbde',
#   'f623b331-1e51-4131-b670-b46d6e88e52e',
#   '7de34128-3a7b-4ad3-a564-e09b8773a041',
#   'd941e8fc-5eda-405e-bc02-6ef0c4e9fd93',
#   'e506ae03-6d86-4bda-8473-55aaca90f8ab',
#   'a2f0f1c4-99a2-4164-bbec-20901c79d1a5',
#   '20f993cf-4165-4277-a4b1-998514aca8d1',
#   'ca7e7ae0-1422-4934-aa05-d1471e9a9071',
#   'e0c59cb0-fec3-47c2-ae7b-7c34ab8f3f68',
#   '67cc4ab9-e971-4e36-8fa4-860e1a61568c',
#   '42434721-6736-4e4e-9f05-1b4f1a4ca657',
#   '0fcc3a45-e77a-44a0-b76c-5103bee578a9',
#   '04605e7d-a7e0-4dcb-88f5-03bbd2ff62f5',
#   'b7f1a01d-3bfc-4dd2-98e4-7e2f56bbc749',
#   '3565b328-3a78-4154-9f73-a876d20facce',
#   'bd3993f1-2767-4960-819f-92a52f2bd43f',
#   '12886885-91f6-43b5-9472-75cbc4d00eca',
#   'f567c84e-a2c9-4ea0-8a8e-1817b0227b7e',
#   'b48efad6-83e3-4804-a5a5-3c074e94fa99',
#   '6e96256c-b9af-4309-af03-6f439e23d851',
#   '009297b2-d171-4593-8260-c40cac420976',
#   '33303ace-621c-4371-8aad-bfe7893cfa65',
#   'b4990691-9ed4-4254-be17-ea917b321746',
#   '54cb0319-549e-4319-a78d-7042c162fcce',
#   'bebdb595-6070-4d31-9997-1fc47e5d885a',
#   '5c9573f1-339f-4aa6-a330-54e955323e7d',
#   'b5e7a854-a245-4f49-9849-ab92ba883a72',
#   '15640a12-4875-4beb-84ec-28107b8b78c2',
#   'a0b50a32-4cd8-441c-855c-2b48984f15a0',
#   'faf42be7-8779-4231-877f-90c6b1531615',
#   'b6bc1818-2f13-469b-acd7-08d60b74181e',
#   '7e8b16a0-9bb4-42c0-8096-6305530ebe10',
#   '583027ee-27a5-4737-b8bb-c7f9f019aa70',
#   '80084c25-97e6-4e37-88be-06e4bc6ad49a',
#   '1d9383be-fb5d-4253-9c08-238e7fd20293',
#   'c5b72b0c-fd5b-45e5-8dd0-5819c4ad9008',
#   '107fc01e-2cfe-47d1-9638-c06d793a6232',
#   '136956cd-8d5e-42e0-9c4d-6a06d5539e66',
#   '6e7da378-2afa-4fb9-b466-aaaa85da1725',
#   '6b3514aa-40e0-4a94-9041-ceda2482955c',
#   'b3e65005-ecbb-4ae6-a78c-559e9b794e65',
#   'd6b3ea9d-9270-4e4c-b0bd-2b7d3f22abc8',
#   '38ca5b35-6e82-4445-b417-461e6bce73c3',
#   '1d87149b-9de0-4309-bea1-96e09d4bba94',
#   '0dbd4aae-738c-462b-b554-08eb589bf871',
#   '7bcb7079-e3b9-40c1-a0ae-2c5fd4f00255',
#   '6ca6df94-65d4-4d2e-9e85-43a360676821',
#   '010bf431-b70b-47ef-a96a-811ebaf0db10',
#   '760bcec8-d44d-4239-83d0-62d8a0adfed1',
#   'f0813d4f-74b6-448b-b4ce-0545058f3f10',
#   '5e637050-27dc-4f93-b401-be762482bf50',
#   'c5bfbcd8-e2e7-49dc-926d-52273444dd2e',
#   'e1d6816e-0d4d-43fe-8c6d-8735ff6c40b5',
#   '524dc597-0cd3-4e8f-baf5-f39deb781860',
#   '171881ae-ee08-4667-ad87-c2219f850245',
#   '2f10e4c7-700b-4e56-8848-ee72f23e86f5',
#   '2122b554-f7c9-4616-af52-28c79066df2a',
#   '7a63afd5-8037-4a3e-9b2c-4efa15408a02',
#   '3c23d316-931c-443e-bb67-babd6289e09d',
#   '7e1e1b94-977f-4799-95e6-0aaa1b2d12a3',
#   '55ee17a7-f423-4331-a996-3a8547fdfc15',
#   '88b0f586-6429-43a4-b817-a9618743bfe2',
#   '2977645d-7b5f-4f4c-9621-417a4008ea7f',
#   '38959826-af98-45b3-8d60-fe337a946587',
#   'fa948e7f-a825-4bb9-ac61-d41e0057bacf',
#   '0f5af3d5-8cbd-4bfd-9cae-3fef1307bd9b',
#   'a9822dc1-015d-4e01-b7be-cb1d3b186d87',
#   '803ca1b7-f439-4f4b-9a87-750f3af01eb4',
#   '37f93cce-ff9e-4bb0-960d-293fdcff053e',
#   'bdf9cdf7-400c-4c7d-a9ea-db7297337280',
#   '28f33ae9-22b5-4211-9997-871633f98f99',
#   '4f3c91c2-ed3e-440e-96c9-a7d51a644d09',
#   '8e5dddf6-aef4-412a-ab81-f98747d3d38c',
#   '88133a7b-f0d0-463c-9f38-9b2473b98dbb',
#   '34d89723-fe07-487a-bcc4-52586143aa5d',
#   'ab24c013-808f-44d5-8c30-15ecb5c38dbf',
#   '41da2544-036b-40b2-be80-8209a51eadbe',
#   '8afaa04f-3c56-4339-97d9-8e52f1b7e6b7',
#   '87e4d313-3464-4ca1-92df-ee4fafcac0a3',
#   '025aa09b-3fc4-4dd2-b96c-0159de6235f4',
#   '7397cf98-bea0-43ed-b2c2-1d32276fa861',
#   '6b1e3b15-040d-4e65-83c7-5703b9479511',
#   '22a78f03-ef1f-44c1-aa87-7456901f4b9c',
#   '7d80f0d1-186a-46dc-8a91-643c96e87fa8',
#   'cbbacc1c-645a-491d-93c3-2e9a415864e2',
#   '0cd31d37-c1b3-4f5e-b3af-8ef0afdf61e8',
#   '068e2a89-6411-4b92-9cd7-3a9a94510960',
#   'e8dc4f52-4fa7-4302-9800-76be27bfcfa1',
#   'dade80b2-0e7d-4b03-935e-019a0639e807',
#   '96d1147e-fe85-4f88-8b09-0b89b7ca31c9',
#   '88213723-e1b3-453d-bb40-af23cfd29650',
#   'f50818cd-0651-42c7-898e-c829dd4efbd1',
#   'fa62e7b0-9689-453a-be37-3388d6a3a1e4',
#   '0a07eae1-2a9e-4c3a-b3e5-9674eb79558a',
#   '7fe4ca88-0260-4f6b-a210-0d72dd1ca27a',
#   'a5b0e12f-e8a6-429a-a378-3158d0fcf2ae',
#   '805b7d93-bf6a-4b86-a938-68cdc662e080',
#   'e9692237-9060-4214-b16e-1440bfdc560c',
#   'e0d8dcef-bf22-46a9-a11e-84229f488a08',
#   '58559bd7-c8e0-4d7e-bc33-f80056573fe0',
#   'bc028ebe-0d71-4c43-8e25-712c1d2530b5',
#   '038a98f6-4c77-468a-a857-0cf77e755c32',
#   '9ea5b6ea-1d35-4cd7-88e6-1cc395b41556',
#   '70ca8af5-afe1-46bb-bcb6-ac49668c6b34',
#   '36802217-3898-4666-ba4a-5a1eb137b449',
#   'ce82c10a-bc51-498c-94d1-eca0aacf6f05',
#   'ff8dd740-6953-4856-94d9-d0d384030661',
#   '89703741-f7e7-44cb-b0c4-29a35d5c75a8',
#   'c38da80e-cc7d-41ff-8198-e909b11ea532',
#   '2407fe24-3b91-479c-9a14-9a36010fa38a',
#   '9dc73510-e99b-44a8-83d1-2ed01790c0e2',
#   'dc821012-c4dd-4f76-9809-fac882bf6e56',
#   'd4aa28e9-0643-4a4f-97d3-4d09f4c669ca',
#   '7abc3ff4-f38e-4737-afbe-d4ae435a95e5',
#   '51c9b0f0-6c81-4472-9347-e9719c843b63',
#   'a74c2979-f881-4145-bfa3-453810a678ba',
#   '1db7ffe5-6bd6-40cf-b4c4-cac61d2bda4f',
#   'f6f41657-2b73-4754-a9b6-057a13274ef8',
#   'a5f33555-30aa-4640-8a34-8f50f36cce90',
#   '708dc86c-5f92-4743-bf9a-6541f9adf4f8',
#   '9e928843-e5fd-4ae0-9768-cf81ba1fb171',
#   '2de9bf1a-1bca-490d-a58e-5d8acb3f9bc4',
#   'd64fcc89-4e9c-412e-94c5-a8325e4bd22c',
#   '7cf8b2ff-0150-4966-ab59-8589c680b4a8',
#   '1a02a0ef-a0df-4425-9d38-642198e72a0b',
#   'fcbecbb8-d390-4481-8af5-6adc9f4fcc35',
#   'b5bb42bb-330d-447e-ac14-bf4714d35d12',
#   '80f6c3a7-720c-4746-bd39-bbc0d1573725',
#   '3fe56c26-f6fd-4413-92a6-bc3abc18ee03',
#   '5930fce4-f9e1-422c-9138-9d3aa33fcb78',
#   'a26608cb-be84-4f2c-9d3f-b31d85ba9f00',
#   '9f028111-7fb4-49e2-8823-a5b7877dda56',
#   '5e7b0635-4e39-4f9b-8935-0876065c1b8d',
#   '75242d4c-0985-4fd6-bf44-5507d36e8b78',
#   'b744bbdf-77ad-4df1-9fc8-b7f9aaa16b38',
#   '3e60e1c2-5225-405f-8969-5663f5d3c061',
#   '611c88cb-abc3-46f8-a866-99001c6768a4',
#   '744350dd-3772-443c-96d6-ca5580d54e99',
#   'ee6ad9bf-2252-450b-a3e7-590305c1984f',
#   'd226851b-17fb-46d2-953a-37599286a1b0',
#   'b7743cae-3300-4aa5-b977-6c380ba8aa3b',
#   'f9451227-7663-43b0-8458-87a478d6953d',
#   '8be53764-45a6-415b-b94a-f213f5e396ff',
#   'c45064e6-1007-471e-84b0-49313b18ecbd',
#   '090acb9e-030c-46ed-835c-7e9cf2a93951',
#   '4ef6421d-6037-4cde-87c7-446321c6f07b',
#   '10ec2f7f-cd77-4d69-9995-dca14fc4b24b',
#   '8529e5cf-256e-4522-b8c7-67f5e07ddedc',
#   'f711a007-4aa4-486a-a06e-fdd42b28c6e0',
#   '55209edc-c3a7-43b2-ae61-e7bc7e5cb09e',
#   '93e47090-4db6-460b-8bf1-7e896ff223a3',
#   'c25a2187-5be3-4e3f-8362-154f1ca189f7',
#   '2ed4782b-a926-4257-964b-a8faef0ae16e',
#   '72217a42-2357-4b43-8c07-7858627809dc',
#   '01d55ad0-f937-495c-9193-8cd6823fee9b',
#   'b41fad04-d971-42ac-ac23-6f70cc14f6b4',
#   'a4382475-0654-444b-86f1-3bfa8cb035ca',
#   '622b8439-fce0-4415-99fe-28e503e07fa9',
#   '4e23ec3d-aac3-41de-8729-805aafccfb2d',
#   '2502efc0-82d6-4077-a54a-ee4c431a1827',
#   'e78ac0e1-0769-4a08-abcf-754d69e3e79c',
#   '8a4130c5-eb12-445a-b79f-377d2895e9b9',
#   '19a75e51-785b-44f4-b7f3-464352c38b4c',
#   '559df9f5-f834-49e2-8269-4295a160427b',
#   'b8f113da-8133-43db-b4ab-201abfb7e473',
#   '1cdb9f63-a038-480f-a320-923d427b91f2',
#   '99f00e33-c02f-4452-baaf-430dc786709a',
#   'e77b74fc-95cf-431e-a7dd-4590ecf662f5',
#   '2ce93eec-e456-4a74-a49f-c40437e1b2af',
#   '0247d147-eb28-42ae-9b73-71f6f698f3a8',
#   '57f7ccc0-0fcb-4a94-a8de-11e0baa126a3',
#   '7a108e1f-ecc0-48f9-906d-4ff4aee345f9',
#   '52611843-6f14-4e5c-83de-f412cf28dd46',
#   '12b4d946-7886-4307-9298-51e549fc1be7',
#   'fdba3f34-38eb-4d19-90ba-055e4d79aa53',
#   '731ef703-0d58-46d0-9d36-5069ca59d057',
#   'd3353dba-1ed6-4fd0-9223-1de91fb56298',
#   '74bf02af-b75d-4631-aa5e-0ea6e8bae244',
#   'e93219f5-add5-46ff-b8aa-98aa6d35e139',
#   '4e100427-6964-4ad1-aef1-2068064e140f',
#   'b6d17f41-10bb-4034-9b25-84906511a34d',
#   'cbbf5b4b-87d2-4c8f-91af-d89d7d079358',
#   '076b4650-0865-4d5b-9024-4e48800a23a5',
#   '1e756b81-6a0e-410d-8307-61560bb1e0b2',
#   '7c32b448-0fee-4d05-839e-475d9d6b6610',
#   '0fc12aaf-443f-4c8c-b751-85955d854ba2',
#   '3683989e-4a2d-42b2-8cf0-a1e8a21afff2',
#   '0549d150-2308-448a-8b36-d7eeb7557501',
#   '38ce3a6f-07ab-45b8-abf9-589025f370e7',
#   'ceefbf89-178c-46a4-86bb-2b1e83261d1e',
#   '8e4d89a2-9b78-4448-8ff8-bbb7204e8889',
#   'cc52a84f-174b-4b8d-af6d-8ce97ae212d2',
#   'ca746423-a2a3-4825-8b56-b795706cf332',
#   '140c3db0-3fa5-494c-8ca0-7bb7fb689280',
#   '3aea4e48-65d8-4da0-8cee-0a52eb38c6b9',
#   '69d5a37f-c6a7-41d1-9e56-a2f68ddc7426',
#   'a669dd90-0dc0-47eb-93c9-40e54ec81707',
#   '01485dc7-fa22-4267-98c6-59b8ed31ee51',
#   '83551b5a-c0ed-4626-b771-59e9071b0b84',
#   '748499b4-1852-4045-9ec0-34788efcd40b',
#   '1231eb6f-96de-4d9e-9709-c370922a4725',
#   'a779f676-d3df-4a95-91f3-f6eb60601296',
#   '4d1836f7-f244-442f-bb64-7e9317f698f9',
#   'f4ff1cea-6111-4f49-b923-b8dceb27f744',
#   '27884114-c55e-4a0c-a168-650409638aef',
#   'b2445c90-e8ee-4a7b-aa78-685f2dd314bd',
#   'bf2c1424-412b-406a-95bd-cd163ef17f6c',
#   'f7e2efd4-ce02-46f9-a477-fd9ed027c0c3',
#   'df99dc7c-b8c5-469d-a67f-0044b73ba242',
#   'a2152302-43b7-4712-9289-35c803c689e4',
#   'e37ed7a7-c837-4973-a197-4a2fc6c71153',
#   '187b1beb-831f-4c0b-9a17-381c3bdb6c90',
#   'bbfd42c6-c47d-4f69-a98b-acc12066d80d',
#   '22803ab4-9b9f-4479-af5d-199e797d9d47',
#   '17c86f95-61d4-4dbe-b748-b1d90e3b22a0',
#   'f40dd4ed-ef2c-4086-bd5f-dabcce52363f',
#   '2d6eeadf-a303-4d3f-ac97-86591ced35ae',
#   '93eec7f3-d316-4049-840b-3cf2e02d18e8',
#   'c25b6a32-1611-4695-93d2-8e0d44d7033e',
#   '4e29d7c5-3f37-47b0-84d1-fad42e65ccc1',
#   'cf327bc1-74b4-45e1-bfb7-d798ba4b80aa',
#   '791af557-902b-473f-84e7-b056e4628589',
#   '48269d1a-4390-46ff-9185-3a5c864d598b',
#   '9f8c4e41-4e47-497f-ba10-6a7e9932387a',
#   '99fa0e9a-6670-46b0-a48e-bdfdc940ebfd',
#   '2812558e-f422-4ca2-b050-8467c0edb9a9',
#   'e8af0f9a-5369-4578-9143-c13c89f1f188',
#   'fa9489d1-cfd1-4310-8eed-a118727b2d11',
#   '916d7c8f-f8b0-4005-90e8-3a9c1ee4df70',
#   '13eeebd4-72c2-4fb9-a05d-d5e0739b26d8',
#   '2305f751-a2e8-4fa0-b1db-1b6b2028a3cd',
#   'bc2a572f-3561-4996-909b-253760e49f6e',
#   '12ae70a6-2ec4-4fd6-a543-1218916e8b91',
#   '69ac0aca-1903-4f84-bc00-4b4240ef93d1',
#   'f75fe39b-12fa-4768-bfb2-3f5b9e0214d4',
#   '0dc66216-c8e4-4afe-bbb7-eadcc534982e',
#   'd1948b78-4333-42cd-bb9b-c30d2da6f467',
#   'a0de0a9b-c58d-43cc-ac9f-4a66987495d0',
#   '00bf06b3-7ed1-4dab-a209-d15c97f27895',
#   '1105dfc8-dc65-422f-9837-1494c9aee523',
#   '6f047e4d-7a05-47bd-8d05-64a30f51ccd6',
#   '996a0d25-c818-4049-99c0-f6309925024f',
#   '3587fc78-e729-49a4-9953-9d5b76c9b1af',
#   'd7fced44-41e2-418e-8f9f-4ca2cc9a9ef3',
#   '133fb944-ae36-4e96-b6bd-64b6747ff5f6',
#   '734508a4-a6ab-4097-9be0-721a1714ccc5',
#   'fcccb972-dece-4cba-a25b-a936099d4980',
#   '344a645f-ebe6-4c69-ab0e-450bb94aafd6',
#   'cf65ae32-0fb6-40ba-92fe-4006dfba2962'],
#  'embeddings': None,
#  'documents': ['Online Tracking:\nA 1-million-site Measurement and Analysis\nSteven Englehardt\nPrinceton University\nste@cs.princeton.edu\nArvind Narayanan\nPrinceton University\narvindn@cs.princeton.edu\nThis is an extended version of our paper that appeared at ACM CCS 2016.\nABSTRACT\nWe present the largest and most detailed measurement of\nonline tracking conducted to date, based on a crawl of the\ntop 1 million websites. We make 15 types of measurements\non each site, including stateful (cookie-based) and stateless',
#   '(ﬁngerprinting-based) tracking, the eﬀect of browser privacy\ntools, and the exchange of tracking data between diﬀerent\nsites (“cookie syncing”). Our ﬁndings include multiple so-\nphisticated ﬁngerprinting techniques never before measured\nin the wild.\nThis measurement is made possible by our open-source\nweb privacy measurement tool, OpenWPM1, which uses an\nautomated version of a full-ﬂedged consumer browser. It\nsupports parallelism for speed and scale, automatic recovery',
#   'from failures of the underlying browser, and comprehensive\nbrowser instrumentation. We demonstrate our platform’s\nstrength in enabling researchers to rapidly detect, quantify,\nand characterize emerging online tracking behaviors.\n1. INTRODUCTION\nWeb privacy measurement — observing websites and ser-\nvices to detect, characterize and quantify privacy-impacting\nbehaviors — has repeatedly forced companies to improve\ntheir privacy practices due to public pressure, press cov-',
#   'erage, and regulatory action [5, 15]. On the other hand,\nweb privacy measurement presents formidable engineering\nand methodological challenges. In the absence of a generic\ntool, it has been largely conﬁned to a niche community of\nresearchers.\nWe seek to transform web privacy measurement into a\nwidespread practice by creating a tool that is useful not just\nto our colleagues but also to regulators, self-regulators, the\npress, activists, and website operators, who are often in the',
#   'dark about third-party tracking on their own domains. We\nalso seek to lessen the burden of continual oversight of web\ntracking and privacy, by developing a robust and modular\nplatform for repeated studies.\nOpenWPM (Section 3) solves three key systems challenges\nfaced by the web privacy measurement community. It does\nso by building on the strengths of past work, while avoiding\nthe pitfalls made apparent in previous engineering eﬀorts.\n(1) We achieve scale through parallelism and robustness by',
#   'utilizing isolated measurement processes similar to FPDetec-\ntive’s platform [2], while still supporting stateful measure-\nments. We’re able to scale to 1 million sites, without having\n1https://github.com/citp/OpenWPM\nto resort to a stripped-down browser [31] (a limitation we\nexplore in detail in Section 3.3). (2) We provide compre-\nhensive instrumentation by expanding on the rich browser\nextension instrumentation of FourthParty [33], without re-',
#   'quiring the researcher to write their own automation code.\n(3) We reduce duplication of work by providing a modular\narchitecture to enable code re-use between studies.\nSolving these problems is hard because the web is not de-\nsigned for automation or instrumentation. Selenium, 2 the\nmain tool for automated browsing through a full-ﬂedged\nbrowser, is intended for developers to test their own web-\nsites. As a result it performs poorly on websites not con-',
#   'trolled by the user and breaks frequently if used for large-\nscale measurements. Browsers themselves tend to suﬀer\nmemory leaks over long sessions. In addition, instrument-\ning the browser to collect a variety of data for later analy-\nsis presents formidable challenges. For full coverage, we’ve\nfound it necessary to have three separate measurement points:\na network proxy, a browser extension, and a disk state mon-\nitor. Further, we must link data collected from these dis-',
#   'parate points into a uniform schema, duplicating much of\nthe browser’s own internal logic in parsing traﬃc.\nA large-scale view of web tracking and privacy.',
#   'parate points into a uniform schema, duplicating much of\nthe browser’s own internal logic in parsing traﬃc.\nA large-scale view of web tracking and privacy.\nIn this paper we report results from a January 2016 mea-\nsurement of the top 1 million sites (Section 4). Our scale\nenables a variety of new insights. We observe for the ﬁrst\ntime that online tracking has a “long tail”, but we ﬁnd a\nsurprisingly quick drop-oﬀ in the scale of individual track-',
#   'ers: trackers in the tail are found on very few sites (Sec-\ntion 5.1). Using a new metric for quantifying tracking (Sec-\ntion 5.2), we ﬁnd that the tracking-protection tool Ghostery\n(https://www.ghostery.com/) is eﬀective, with some caveats\n(Section 5.5). We quantify the impact of trackers and third\nparties on HTTPS deployment (Section 5.3) and show that\ncookie syncing is pervasive (Section 5.6).\nTurning to browser ﬁngerprinting, we revisit an inﬂuential',
#   '2014 study on canvas ﬁngerprinting [1] with updated and im-\nproved methodology (Section 6.1). Next, we report on sev-\neral types of ﬁngerprinting never before measured at scale:\nfont ﬁngerprinting using canvas (which is distinct from can-\nvas ﬁngerprinting; Section 6.2), and ﬁngerprinting by abus-\ning the WebRTC API (Section 6.3), the Audio API (Section\n6.4), and the Battery Status API (6.5). Finally, we show\nthat in contrast to our results in Section 5.5, existing pri-',
#   'vacy tools are not eﬀective at detecting these newer and\nmore obscure ﬁngerprinting techniques.\n2http://www.seleniumhq.org/',
#   'Overall, our results show cause for concern, but also en-\ncouraging signs. In particular, several of our results suggest\nthat while online tracking presents few barriers to entry,\ntrackers in the tail of the distribution are found on very few\nsites and are far less likely to be encountered by the av-\nerage user. Those at the head of the distribution, on the\nother hand, are owned by relatively few companies and are\nresponsive to the scrutiny resulting from privacy studies.',
#   'We envision a future where measurement provides a key\nlayer of oversight of online privacy. This will be especially\nimportant given that perfectly anticipating and preventing\nall possible privacy problems (whether through blocking tools\nor careful engineering of web APIs) has proved infeasible.\nTo enable such oversight, we plan to make all of our data\npublicly available (OpenWPM is already open-source). We\nexpect that measurement will be useful to developers of pri-',
#   'vacy tools, to regulators and policy makers, journalists, and\nmany others.\n2. BACKGROUND AND RELATED WORK\nBackground: third-party online tracking. As users\nbrowse and interact with websites, they are observed by both\n“ﬁrst parties,” which are the sites the user visits directly, and\n“third parties” which are typically hidden trackers such as\nad networks embedded on most web pages. Third parties\ncan obtain users’ browsing histories through a combination',
#   'of cookies and other tracking technologies that allow them\nto uniquely identify users, and the “referer” header that tells\nthe third party which ﬁrst-party site the user is currently\nvisiting. Other sensitive information such as email addresses\nmay also be leaked to third parties via the referer header.\nWeb privacy measurement platforms. The closest\ncomparisons to OpenWPM are other open web privacy mea-\nsurement platforms, which we now review. We consider a',
#   'tool to be a platform if is is publicly available and there is\nsome generality to the types of studies that can be performed\nusing it. In some cases, OpenWPM has directly built upon\nexisting platforms, which we make explicit note of.\nFPDetective is the most similar platform to OpenWPM.\nFPDetective uses a hybrid PhantomJS and Chromium based\nautomation infrastructure [2], with both native browser code\nand a proxy for instrumentation. In the published study, the',
#   'platform was used for the detection and analysis of ﬁnger-\nprinters, and much of the included instrumentation was built\nto support that. The platform allows researchers to conduct\nadditional experiments by replacing a script which is exe-\ncuted with each page visit, which the authors state can be\neasily extended for non-ﬁngerprinting studies.\nOpenWPM diﬀers in several ways from FPDetective: (1)\nit supports both stateful and stateless measurements, whereas',
#   'FPDetective only supports stateless (2) it includes generic\ninstrumentation for both stateless and stateful tracking, en-\nabling a wider range of privacy studies without additional\nchanges to the infrastructure (3) none of the included instru-\nmentation requires native browser code, making it easier to\nupgrade to new or diﬀerent versions of the browser, and (4)\nOpenWPM uses a high-level command-based architecture,\nwhich supports command re-use between studies.',
#   'Chameleon Crawler is a Chromium based crawler that uti-\nlizes the Chameleon3 browser extension for detecting browser\nﬁngerprinting. Chameleon Crawler uses similar automation\n3https://github.com/ghostwords/chameleon\ncomponents, but supports a subset of OpenWPM’s instru-\nmentation.\nFourthParty is a Firefox plug-in for instrumenting the\nbrowser and does not handle automation [33]. OpenWPM\nhas incorporated and expanded upon nearly all of Fourth-\nParty’s instrumentation (Section 3).',
#   'WebXray is a PhantomJS based tool for measuring HTTP\ntraﬃc [31]. It has been used to study third-party inclusions\non the top 1 million sites, but as we show in Section 3.3,\nmeasurements with a stripped-down browser have the po-',
#   'traﬃc [31]. It has been used to study third-party inclusions\non the top 1 million sites, but as we show in Section 3.3,\nmeasurements with a stripped-down browser have the po-\ntential to miss a large number of resource loads.\nTrackingObserveris a Chrome extension that detects track-\ning and exposes APIs for extending its functionality such as\nmeasurement and blocking [48].\nXRay [27] and AdFisher [9] are tools for running auto-\nmated personalization detection experiments. AdFisher builds',
#   'on similar technologies as OpenWPM (Selenium, xvfb), but\nis not intended for tracking measurements.\nCommon Crawl 4 uses an Apache Nutch based crawler.\nThe Common Crawl dataset is the largest publicly available\nweb crawl5, with billions of page visits. However, the crawler\nused does not execute Javascript or other dynamic content\nduring a page visit. Privacy studies which use the dataset\n[49] will miss dynamically loaded content, which includes\nmany advertising resources.',
#   'Crowd-sourcing of web privacy and personalization mea-\nsurement is an important alternative to automated brows-\ning. $heriﬀ and Bobble are two platforms for measuring per-\nsonalization [35, 65]. Two major challenges are participant\nprivacy and providing value to users to incentivize partici-\npation.\nPrevious ﬁndings. Krishnarmurthy and Wills [24] pro-\nvide much of the early insight into web tracking, showing the\ngrowth of the largest third-party organizations from 10% to',
#   '20-60% of top sites between 2005 and 2008. In the following\nyears, studies show a continual increase in third-party track-\ning and in the diversity of tracking techniques [33, 48, 20,\n2, 1, 4]. Lerner et al. also ﬁnd an increase in the prevalence\nand complexity of tracking, as well as an increase in the\ninterconnectedness of the ecosystem by analyzing Internet\nArchive data from 1996 to 2016 [29]. Fruchter et al. stud-\nied geographic variations in tracking [17]. More recently,',
#   'Libert studied third-party HTTP requests on the top 1 mil-\nlion sites [31], providing view of tracking across the web. In\nthis study, Libert showed that Google can track users across\nnearly 80% of sites through its various third-party domains.\nWeb tracking has expanded from simple HTTP cookies to\ninclude more persistent tracking techniques. Soltani et al.\nﬁrst examined the use of ﬂash cookies to “respawn” or re-\ninstantiate HTTP cookies [53], and Ayenson et al. showed',
#   'how sites were using cache E-Tags and HTML5 localStor-\nage for the same purpose [6]. These discoveries led to media\nbacklash [36, 30] and legal settlements [51, 10] against the\ncompanies participating in the practice. However several\nfollow up studies by other research groups conﬁrmed that,\ndespite a reduction in usage (particularly in the U.S.), the\ntechnique is still used for tracking [48, 34, 1].\nDevice ﬁngerprinting is a persistent tracking technique',
#   'which does not require a tracker to set any state in the user’s\n4https://commoncrawl.org\n5https://aws.amazon.com/public-data-sets/common-\ncrawl/',
#   'browser. Instead, trackers attempt to identify users by a\ncombination of the device’s properties. Within samples of\nover 100,000 browsers, 80-90% of desktop and 81% of mobile\ndevice ﬁngerprints are unique [12, 26]. New ﬁngerprinting\ntechniques are continually discovered [37, 43, 16], and are\nsubsequently used to track users on the web [41, 2, 1]. In\nSection 6.1 we present several new ﬁngerprinting techniques\ndiscovered during our measurements.\nPersonalization measurement. Measurement of track-',
#   'ing is closely related to measurement of personalization,\nsince the question of what data is collected leads to the ques-\ntion of how that data is used. The primary purpose of online\ntracking is behavioral advertising — showing ads based on\nthe user’s past activity. Datta et al. highlight the incom-\npleteness of Google’s Ad Settings transparency page and\nprovide several empirical examples of discriminatory and\npredatory ads [9]. L´ ecuyer et al. develop XRay, a system',
#   'for inferring which pieces of user data are used for personal-\nization [27]. Another system by some of the same authors is\nSunlight which improves upon their previous methodology\nto provide statistical conﬁdence of their targeting inferences\n[28].\nMany other practices that raise privacy or ethical con-\ncerns have been studied: price discrimination, where a site\nshows diﬀerent prices to diﬀerent consumers for the same\nproduct [19, 63]; steering, a gentler form of price discrimina-',
#   'tion where a product search shows diﬀerently-priced results\nfor diﬀerent users [32]; and the ﬁlter bubble , the supposed\neﬀect that occurs when online information systems person-\nalize what is shown to a user based on what the user viewed\nin the past [65].\nWeb security measurement. Web security studies of-\nten use similar methods as web privacy measurement, and\nthe boundary is not always clear. Yue and Wang modiﬁed\nthe Firefox browser source code in order to perform a mea-',
#   'surement of insecure Javascript implementations on the web\n[67]. Headless browsers have been used in many web security\nmeasurements, for example: to measure the amount of third-\nparty Javascript inclusions across many popular sites and\nthe vulnerabilities that arise from how the script is embed-\nded [40], to measure the presence of security seals on the top\n1 million sites [62], and to study stand-alone password gener-\nators and meters on the web [60]. Several studies have used',
#   'Selenium-based frameworks, including: to measure and cat-\negorize malicious advertisements displayed while browsing\npopular sites [68], to measure the presence of malware and\nother vulnerabilities on live streaming websites [46], to study\nHSTS deployment [21], to measure ad-injecting browser ex-\ntensions [66], and to emulate users browsing malicious web\nshells with the goal of detecting client-side homephoning\n[55]. Other studies have analyzed Flash and Javascript el-',
#   'ements of webpages to measure security vulnerabilities and\nerror-prone implementations [42, 61].\n3. MEASUREMENT PLATFORM\nAn infrastructure for automated web privacy measure-\nment has three components: simulating users, recording ob-\nservations (response metadata, cookies, behavior of scripts,\netc.), and analysis. We set out to build a platform that\ncan automate the ﬁrst two components and can ease the\nresearcher’s analysis task. We sought to make OpenWPM\nT ask\nManager\nData\nAggregator\nWWW',
#   'SeleniumBrowser\nManager Browser\n...\nBrowser\nManager Browser\nBrowser\nManager Browser\nInstrumentation Layer\nAnalysis\nScripts\nSelenium\nSelenium\nFigure 1: High-level overview of OpenWPM\nThe task manager monitors browser managers, which con-\nvert high-level commands into automated browser actions.\nThe data aggregator receives and pre-processes data from\ninstrumentation.\ngeneral, modular, and scalable enough to support essentially\nany privacy measurement.',
#   'OpenWPM is open source and has already been used for\nmeasurement by several published studies. Section 3.4 in',
#   'general, modular, and scalable enough to support essentially\nany privacy measurement.\nOpenWPM is open source and has already been used for\nmeasurement by several published studies. Section 3.4 in\nthe supplementary materials examines the advanced features\nused by each study. In this paper we present, for the ﬁrst\ntime, the design and evaluation of the platform and highlight\nits strengths through several new measurements.\n3.1 Design Motivations\nOpenWPM builds on similar technologies as many previ-',
#   'ous platforms, but has several key design diﬀerences to sup-\nports modular, comprehensive, and maintainable measure-\nment. Our platform supports stateful measurements while\nFPDetective [2] does not. Stateful measurements are im-\nportant for studying the tracking ecosystem. Ad auctions\nmay vary based on cookie data. A stateless browser always\nappears to be a new user, which skews cookie syncing mea-\nsurements. In addition to cookie syncing studied in this',
#   'paper, stateful measurements have allowed our platform to\nbe used to study cookie respawning [1] and replicate realistic\nuser proﬁles [14].\nMany past platforms rely on native instrumentation code\n[39, 52, 2], which have a high maintenance cost and, in some\ncases a high cost-per-API monitored. In our platform, the\ncost of monitoring new APIs is minimal (Section 3.3) and\nAPIs can be enabled or disabled in the add-on without re-\ncompiling the browser or rendering engine. This allows us to',
#   'monitor a larger number of APIs. Native codebase changes\nin other platforms require constant merges as the upstream\ncodebase evolves and complete rewrites to support alterna-\ntive browsers.\n3.2 Design and Implementation\nWe divided our browser automation and data collection\ninfrastructure into three main modules: browser managers\nwhich act as an abstraction layer for automating individual\nbrowser instances, a user-facing task manager which serves',
#   'to distribute commands to browser managers, and a data\naggregator, which acts as an abstraction layer for browser in-\nstrumentation. The researcher interacts with the task man-\nager via an extensible, high-level, domain-speciﬁc language\nfor crawling and controlling the browser instance. The entire\nplatform is built using Python and Python libraries.',
#   'Browser driver: Providing realism and support for\nweb technologies. We considered a variety of choices to\ndrive measurements, i.e., to instruct the browser to visit a set\nof pages (and possibly to perform a set of actions on each).\nThe two main categories to choose from are lightweight browsers\nlike PhantomJS (an implementation of WebKit), and full-\nﬂedged browsers like Firefox and Chrome. We chose to use\nSelenium, a cross-platform web driver for Firefox, Chrome,',
#   'Internet Explorer, and PhantomJS. We currently use Sele-\nnium to drive Firefox, but Selenium’s support for multiple\nbrowsers makes it easy to transition to others in the future.\nBy using a consumer browser, all technologies that a typ-\nical user would have access to (e.g., HTML5 storage op-\ntions, Adobe Flash) are also supported by measurement\ninstances. The alternative, PhantomJS, does not support\nWebGL, HTML5 Audio and Video, CSS 3-D, and browser',
#   'plugins (like Flash), making it impossible to run measure-\nments on the use of these technologies [45]. In retrospect\nthis has proved to be a sound choice. Without full support\nfor new web technologies we would not have been able to\ndiscover and measure the use of the AudioContext API for\ndevice ﬁngerprinting as discussed in Section 6.4.\nFinally the use of real browsers also allows us to test the\neﬀects of consumer browser extensions. We support run-',
#   'ning measurements with extensions such as Ghostery and\nHTTPS Everywhere as well as enabling Firefox privacy set-\ntings such third-party cookie blocking and the new Tracking\nProtection feature. New extensions can easily be supported\nwith only a few extra lines of code (Section 3.3). See Sec-\ntion 5.3 and Section 5.5 for analyses of measurements run\nwith these browser settings.\nBrowser managers: Providing stability. During the\ncourse of a long measurement, a variety of unpredictable',
#   'events such as page timeouts or browser crashes could halt\nthe measurement’s progress or cause data loss or corruption.\nA key disadvantage of Selenium is that it frequently hangs\nindeﬁnitely due to its blocking API [50], as it was designed to\nbe a tool for webmasters to test their own sites rather than\nan engine for large-scale measurements. Browser managers\nprovide an abstraction layer around Selenium, isolating it\nfrom the rest of the components.',
#   'Each browser manager instantiates a Selenium instance\nwith a speciﬁed conﬁguration of preferences, such as block-\ning third-party cookies. It is responsible for converting high-\nlevel platform commands (e.g. visiting a site) into speciﬁc\nSelenium subroutines. It encapsulates per-browser state, en-\nabling recovery from browser failures. To isolate failures,\neach browser manager runs as a separate process.\nWe support launching measurement instances in a “head-',
#   'less” container, by using the pyvirtualdisplay library to in-\nterface with Xvfb, which draws the graphical interface of the\nbrowser to a virtual frame buﬀer.\nTask manager: Providing scalability and abstrac-\ntion. The task manager provides a scriptable command-line\ninterface for controlling multiple browsers simultaneously.\nCommands can be distributed to browsers either synchro-\nnized or ﬁrst-come-ﬁrst-serve. Each command is launched\nin a per-browser command execution thread.',
#   'The command-execution thread handles errors in its cor-\nresponding browser manager automatically. If the browser\nmanager crashes, times out, or exceeds memory limits, the\nthread enters a crash recovery routine. In this routine, the\nmanager archives the current browser proﬁle, kills all current\nprocesses, and loads the archive (which includes cookies and\nhistory) into a fresh browser with the same conﬁguration.\nData Aggregator: Providing repeatability. Repeata-',
#   'bility can be achieved logging data in a standardized format,\nso research groups can easily share scripts and data. We ag-\ngregate data from all instrumentation components in a cen-\ntral and structured location. The data aggregator receives',
#   'so research groups can easily share scripts and data. We ag-\ngregate data from all instrumentation components in a cen-\ntral and structured location. The data aggregator receives\ndata during the measurement, manipulates it as necessary,\nand saves it on disk keyed back to a speciﬁc page visit and\nbrowser. The aggregator exists within its own process, and\nis accessed through a socket interface which can easily be\nconnected to from any number of browser managers or in-\nstrumentation processes.',
#   'We currently support two data aggregators: a structured\nSQLite aggregator for storing relational data and a Lev-\nelDB aggregator for storing compressed web content. The\nSQLite aggregator stores the majority of the measurement\ndata, including data from both the proxy and the exten-\nsion (described below). The LevelDB aggregator is designed\nto store de-duplicated web content, such as Javascript or\nHTML ﬁles. The aggregator checks if a hash of the content',
#   'is present in the database, and if not compresses the content\nand adds it to the database.\nInstrumentation: Supporting comprehensive and\nreusable measurement. We provide the researcher with\ndata access at several points: (1) raw data on disk, (2) at the\nnetwork level with an HTTP proxy, and (3) at the Javascript\nlevel with a Firefox extension. This provides nearly full cov-\nerage of a browser’s interaction with the web and the sys-\ntem. Each level of instrumentation keys data with the top',
#   'level site being visited and the current browser id, making\nit possible to combine measurement data from multiple in-\nstrumentation sources for each page visit.\nDisk Access — We include instrumentation that collects\nchanges to Flash LSOs and the Firefox cookie database after\neach page visit. This allows a researcher to determine which\ndomains are setting Flash cookies, and to record access to\ncookies in the absence of other instrumentation\nHTTP Data — After examining several Python HTTP',
#   'proxies, we chose to use Mitmproxy6 to record all HTTP Re-\nquest and Response headers. We generate and load a certiﬁ-\ncate into Firefox to capture HTTPS data alongside HTTP.\nAdditionally, we use the HTTP proxy to dump the con-\ntent of any Javascript ﬁle requested during a page visit. We\nuse both Content-Type and ﬁle extension checking to detect\nscripts in the proxy. Once detected, a script is decompressed\n(if necessary) and hashed. The hash and content are sent to',
# ...
#    'total_pages': 20},
#   {'keywords': '',
#    'trapped': '/False',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'page_label': '17',
#    'page': 16,
#    'creator': 'LaTeX with hyperref package',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'total_pages': 20,
#    'author': '',
#    'producer': 'pdfTeX-1.40.16',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'subject': '',
#    'title': '',
#    'moddate': '2016-10-25T21:39:52+00:00'},
#   {'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'page_label': '17',
#    'author': '',
#    'page': 16,
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'total_pages': 20,
#    'subject': '',
#    'title': '',
#    'trapped': '/False',
#    'producer': 'pdfTeX-1.40.16',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'keywords': '',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'creator': 'LaTeX with hyperref package'},
#   {'trapped': '/False',
#    'producer': 'pdfTeX-1.40.16',
#    'total_pages': 20,
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'page': 17,
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'keywords': '',
#    'subject': '',
#    'creator': 'LaTeX with hyperref package',
#    'author': '',
#    'title': '',
#    'page_label': '18'},
#   {'title': '',
#    'author': '',
#    'page_label': '18',
#    'producer': 'pdfTeX-1.40.16',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'subject': '',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'creator': 'LaTeX with hyperref package',
#    'page': 17,
#    'total_pages': 20,
#    'trapped': '/False',
#    'keywords': '',
#    'moddate': '2016-10-25T21:39:52+00:00'},
#   {'creationdate': '2016-10-25T21:39:52+00:00',
#    'author': '',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'creator': 'LaTeX with hyperref package',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'total_pages': 20,
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'producer': 'pdfTeX-1.40.16',
#    'subject': '',
#    'keywords': '',
#    'page_label': '18',
#    'title': '',
#    'page': 17,
#    'trapped': '/False'},
#   {'moddate': '2016-10-25T21:39:52+00:00',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'page': 17,
#    'total_pages': 20,
#    'author': '',
#    'page_label': '18',
#    'trapped': '/False',
#    'title': '',
#    'producer': 'pdfTeX-1.40.16',
#    'creator': 'LaTeX with hyperref package',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'keywords': '',
#    'subject': ''},
#   {'creationdate': '2016-10-25T21:39:52+00:00',
#    'subject': '',
#    'title': '',
#    'total_pages': 20,
#    'producer': 'pdfTeX-1.40.16',
#    'trapped': '/False',
#    'page_label': '18',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'keywords': '',
#    'page': 17,
#    'creator': 'LaTeX with hyperref package',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'author': ''},
#   {'title': '',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'total_pages': 20,
#    'producer': 'pdfTeX-1.40.16',
#    'keywords': '',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'author': '',
#    'creator': 'LaTeX with hyperref package',
#    'page_label': '18',
#    'subject': '',
#    'page': 17,
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'trapped': '/False'},
#   {'page_label': '18',
#    'title': '',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'author': '',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'keywords': '',
#    'subject': '',
#    'creator': 'LaTeX with hyperref package',
#    'total_pages': 20,
#    'trapped': '/False',
#    'page': 17,
#    'producer': 'pdfTeX-1.40.16',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1'},
#   {'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'keywords': '',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'producer': 'pdfTeX-1.40.16',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'creator': 'LaTeX with hyperref package',
#    'subject': '',
#    'page_label': '18',
#    'page': 17,
#    'author': '',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'total_pages': 20,
#    'trapped': '/False',
#    'title': ''},
#   {'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'total_pages': 20,
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'creator': 'LaTeX with hyperref package',
#    'page_label': '18',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'page': 17,
#    'keywords': '',
#    'subject': '',
#    'trapped': '/False',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'producer': 'pdfTeX-1.40.16',
#    'author': '',
#    'title': ''},
#   {'creationdate': '2016-10-25T21:39:52+00:00',
#    'title': '',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'creator': 'LaTeX with hyperref package',
#    'total_pages': 20,
#    'author': '',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'keywords': '',
#    'subject': '',
#    'trapped': '/False',
#    'producer': 'pdfTeX-1.40.16',
#    'page_label': '18',
#    'page': 17,
#    'moddate': '2016-10-25T21:39:52+00:00'},
#   {'creator': 'LaTeX with hyperref package',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'subject': '',
#    'page_label': '18',
#    'trapped': '/False',
#    'author': '',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'page': 17,
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'title': '',
#    'keywords': '',
#    'total_pages': 20,
#    'producer': 'pdfTeX-1.40.16'},
#   {'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'author': '',
#    'keywords': '',
#    'title': '',
#    'page': 17,
#    'subject': '',
#    'trapped': '/False',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'total_pages': 20,
#    'page_label': '18',
#    'producer': 'pdfTeX-1.40.16',
#    'creator': 'LaTeX with hyperref package'},
#   {'producer': 'pdfTeX-1.40.16',
#    'page_label': '18',
#    'title': '',
#    'keywords': '',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'subject': '',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'trapped': '/False',
#    'creator': 'LaTeX with hyperref package',
#    'author': '',
#    'page': 17,
#    'total_pages': 20,
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1'},
#   {'moddate': '2016-10-25T21:39:52+00:00',
#    'page_label': '18',
#    'subject': '',
#    'producer': 'pdfTeX-1.40.16',
#    'page': 17,
#    'title': '',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'total_pages': 20,
#    'trapped': '/False',
#    'creator': 'LaTeX with hyperref package',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'author': '',
#    'keywords': '',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf'},
#   {'subject': '',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'title': '',
#    'trapped': '/False',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'keywords': '',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'producer': 'pdfTeX-1.40.16',
#    'total_pages': 20,
#    'page_label': '19',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'author': '',
#    'page': 18,
#    'creator': 'LaTeX with hyperref package'},
#   {'creator': 'LaTeX with hyperref package',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'author': '',
#    'subject': '',
#    'title': '',
#    'trapped': '/False',
#    'keywords': '',
#    'page_label': '19',
#    'page': 18,
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'total_pages': 20,
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'producer': 'pdfTeX-1.40.16',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1'},
#   {'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'keywords': '',
#    'producer': 'pdfTeX-1.40.16',
#    'subject': '',
#    'author': '',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'trapped': '/False',
#    'creator': 'LaTeX with hyperref package',
#    'page': 18,
#    'title': '',
#    'total_pages': 20,
#    'page_label': '19'},
#   {'keywords': '',
#    'title': '',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'producer': 'pdfTeX-1.40.16',
#    'subject': '',
#    'author': '',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'creator': 'LaTeX with hyperref package',
#    'page_label': '19',
#    'total_pages': 20,
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'trapped': '/False',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'page': 18},
#   {'page_label': '20',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'title': '',
#    'subject': '',
#    'author': '',
#    'page': 19,
#    'total_pages': 20,
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'creator': 'LaTeX with hyperref package',
#    'producer': 'pdfTeX-1.40.16',
#    'trapped': '/False',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'keywords': ''},
#   {'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'creator': 'LaTeX with hyperref package',
#    'author': '',
#    'title': '',
#    'producer': 'pdfTeX-1.40.16',
#    'keywords': '',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'total_pages': 20,
#    'page_label': '20',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'trapped': '/False',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'subject': '',
#    'page': 19},
#   {'keywords': '',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'producer': 'pdfTeX-1.40.16',
#    'title': '',
#    'total_pages': 20,
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'creator': 'LaTeX with hyperref package',
#    'author': '',
#    'trapped': '/False',
#    'page_label': '20',
#    'page': 19,
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'subject': ''},
#   {'trapped': '/False',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'creator': 'LaTeX with hyperref package',
#    'author': '',
#    'page': 19,
#    'subject': '',
#    'title': '',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'keywords': '',
#    'total_pages': 20,
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'producer': 'pdfTeX-1.40.16',
#    'page_label': '20',
#    'moddate': '2016-10-25T21:39:52+00:00'},
#   {'author': '',
#    'total_pages': 20,
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'creator': 'LaTeX with hyperref package',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'title': '',
#    'subject': '',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'trapped': '/False',
#    'page_label': '20',
#    'page': 19,
#    'producer': 'pdfTeX-1.40.16',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'keywords': ''},
#   {'page_label': '18',
#    'subject': '',
#    'producer': 'pdfTeX-1.40.16',
#    'total_pages': 20,
#    'author': '',
#    'creator': 'LaTeX with hyperref package',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'page': 17,
#    'keywords': '',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'title': '',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'trapped': '/False'},
#   {'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'subject': '',
#    'trapped': '/False',
#    'total_pages': 20,
#    'page': 17,
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'title': '',
#    'producer': 'pdfTeX-1.40.16',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'author': '',
#    'page_label': '18',
#    'creator': 'LaTeX with hyperref package',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'keywords': ''},
#   {'moddate': '2016-10-25T21:39:52+00:00',
#    'author': '',
#    'total_pages': 20,
#    'page': 17,
#    'title': '',
#    'producer': 'pdfTeX-1.40.16',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'keywords': '',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'page_label': '18',
#    'trapped': '/False',
#    'subject': '',
#    'creator': 'LaTeX with hyperref package'},
#   {'subject': '',
#    'title': '',
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'page': 7,
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'creator': 'LaTeX with hyperref package',
#    'producer': 'pdfTeX-1.40.16',
#    'keywords': '',
#    'trapped': '/False',
#    'page_label': '8',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'author': '',
#    'total_pages': 20}]}

# %% [markdown]
# ### ChromaDB CRUD-операции

# %% [markdown]
# #### Create

# %%
new_document_id = str(uuid4())
new_document_source = {'source': 'my_thoughts'}
new_document = 'At the moment, protection against digital surveillance is popularized and rooted in the dark side of the Internet.'

example_db._collection.add(
  embeddings=embedding_model.embed_documents([new_document]),
  documents=[new_document],
  metadatas=[new_document_source],
  ids=[new_document_id]
)

# %%
example_db._collection.count()
# Out:
# 527

# %% [markdown]
# #### Read

# %%
example_db.get(new_document_id)
# Out:
# {'ids': ['651a0c91-8dc3-473f-a140-1ed6381cb03c'],
#  'embeddings': None,
#  'documents': ['At the moment, protection against digital surveillance is popularized and rooted in the dark side of the Internet.'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'source': 'my_thoughts'}]}

# %% [markdown]
# #### Update

# %%
docs = example_db.similarity_search('dark side of the Internet')
print(docs)
# Out:
# page_content='At the moment, protection against digital surveillance is popularized and rooted in the dark side of the Internet.' metadata={'source': 'my_thoughts'}

# %%
docs[0].metadata = { 'source': "not_my_thoughts" }

# Epstein files reference ( ˶°ㅁ°) !!
docs[0].page_content = 'At the moment, protection against digital surveillance is popularized ██████████████████████████████'

example_db.update_document(new_document_id, docs[0])

print(example_db._collection.get(ids=[new_document_id]))
# Out:
# {'ids': ['8f761e18-d409-4aee-b4b0-83e9cb159100'], 'embeddings': None, 'documents': ['At the moment, protection against digital surveillance is popularized ██████████████████████████████'], 'uris': None, 'included': ['metadatas', 'documents'], 'data': None, 'metadatas': [{'source': 'not_my_thoughts'}]}

# %% [markdown]
# #### Delete

# %%
print('Было:', example_db._collection.count())

example_db._collection.delete(ids=new_document_id)

print('Стало:', example_db._collection.count())
# Out:
# Было: 264
# Стало: 263

# %% [markdown]
# #### Filtering

# %%
example_db.get(where_document={'$contains': 'cookie-syncing parties'})
# Out:
# {'ids': ['ed38893e-cf24-40ed-93f0-ce7beff59935',
#   '5ed14bfe-2d06-4a99-a4e6-ff145d841d1b'],
#  'embeddings': None,
#  'documents': ['other third parties (this includes both events where it is a\nreferer and where it is a receiver). We present details of the\ntop cookie-syncing parties in Appendix 13.3.\nMore interestingly, we ﬁnd that the vast majority of top\nthird parties sync cookies with at least one other party: 45\nof the top 50, 85 of the top 100, 157 of the top 200, and\n460 of the top 1,000. This adds further evidence that cookie\nsyncing is an under-researched privacy concern.',
#   'other third parties (this includes both events where it is a\nreferer and where it is a receiver). We present details of the\ntop cookie-syncing parties in Appendix 13.3.\nMore interestingly, we ﬁnd that the vast majority of top\nthird parties sync cookies with at least one other party: 45\nof the top 50, 85 of the top 100, 157 of the top 200, and\n460 of the top 1,000. This adds further evidence that cookie\nsyncing is an under-researched privacy concern.'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'subject': '',
#    'trapped': '/False',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'author': '',
#    'page': 10,
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf',
#    'producer': 'pdfTeX-1.40.16',
#    'title': '',
#    'total_pages': 20,
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'page_label': '11',
#    'creator': 'LaTeX with hyperref package',
#    'keywords': '',
#    'moddate': '2016-10-25T21:39:52+00:00'},
#   {'keywords': '',
#    'author': '',
#    'page': 10,
#    'page_label': '11',
#    'creationdate': '2016-10-25T21:39:52+00:00',
#    'producer': 'pdfTeX-1.40.16',
#    'moddate': '2016-10-25T21:39:52+00:00',
#    'title': '',
#    'creator': 'LaTeX with hyperref package',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1',
#    'subject': '',
#    'trapped': '/False',
#    'total_pages': 20,
#    'source': 'https://www.cs.princeton.edu/~arvindn/publications/OpenWPM_1_million_site_tracking_measurement.pdf'}]}

# %% [markdown]
# <img src="https://media.tenor.com/5X5MilxS3xUAAAAi/theresa-civilight-eterna.gif" width="600" height="300" />
